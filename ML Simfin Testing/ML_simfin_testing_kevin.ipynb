# %%
import pandas as pd
import numpy as np
import simfin as sf
from simfin.names import *

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import export_text
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score, accuracy_score

# %% [markdown]
# ### Data Pulling (from SimFin) --> api_calls.py

# %%
API_KEY = 'MbOGeJgi6qQjgYbb58oBVQDaObxEZzXg'

# SimFin data-directory.
sf.set_data_dir('~/simfin_data/')
# SimFin load API key or use free data.
sf.load_api_key('MbOGeJgi6qQjgYbb58oBVQDaObxEZzXg')

# %%
market = 'us'

# Add this date-offset to the fundamental data such as
# Income Statements etc., because the REPORT_DATE is not
# when it was actually made available to the public,
# which can be 1, 2 or even 3 months after the Report Date.
offset = pd.DateOffset(days=60)

# Refresh the fundamental datasets (Income Statements etc.)
# every 30 days.
refresh_days = 30

# Refresh the dataset with shareprices every 10 days.
refresh_days_shareprices = 10

# %%
hub = sf.StockHub(market=market, offset=offset,
                  refresh_days=refresh_days,
                  refresh_days_shareprices=refresh_days_shareprices)

df_fin_signals = hub.fin_signals(variant='daily')
df_growth_signals = hub.growth_signals(variant='daily')
df_val_signals = hub.val_signals(variant='daily')
# Out:
# Dataset "us-income-ttm" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-balance-ttm" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-cashflow-ttm" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-shareprices-daily" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Cache-file 'fin_signals-2a38bb7d.pickle' not on disk.
# - Running function fin_signals() ...
# c:\users\kevin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Done!
# - Saving cache-file to disk ... Done!
# Dataset "us-income-quarterly" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Dataset "us-cashflow-quarterly" not on disk.
# - Downloading ... 100.0%
# - Extracting zip-file ... Done!
# - Loading from disk ... Done!
# Cache-file 'growth_signals-2a38bb7d.pickle' not on disk.
# - Running function growth_signals() ... Done!
# - Saving cache-file to disk ... Done!
# Cache-file 'val_signals-739b68a6.pickle' not on disk.
# - Running function val_signals() ... Done!
# - Saving cache-file to disk ... Done!

# %% [markdown]
# ### Data Cleaning/Manipulation

# %%
# Combine the DataFrames.
dfs = [df_fin_signals, df_growth_signals, df_val_signals]
df_signals = pd.concat(dfs, axis=1)

# Remove all rows with only NaN values.
df = df_signals.dropna(how='all').reset_index(drop=True)

# List of the columns before removing any.
columns_before = df_signals.columns

# Threshold for the number of rows that must be NaN for each column.
thresh = 0.75 * len(df_signals.dropna(how='all'))

# Remove all columns which don't have sufficient data.
df_signals = df_signals.dropna(axis='columns', thresh=thresh)

# List of the columns after the removal.
columns_after = df_signals.columns

# Show the columns that were removed.
columns_before.difference(columns_after)

# Name of the new column for the returns.
TOTAL_RETURN_1_3Y = 'Total Return 1-3 Years'

# Calculate the mean log-returns for all 1-3 year periods.
df_returns_1_3y = \
    hub.mean_log_returns(name=TOTAL_RETURN_1_3Y,
                         future=True, annualized=True,
                         min_years=1, max_years=3)

dfs = [df_signals, df_returns_1_3y]
df_sig_rets = pd.concat(dfs, axis=1)

# Clip the signals and returns at their 5% and 95% quantiles.
# We do not set them to NaN because it would remove too much data.
df_sig_rets = sf.winsorize(df_sig_rets)

# Remove all rows with missing values (NaN)
# because scikit-learn cannot handle that.
df_sig_rets = df_sig_rets.dropna(how='any')

# Remove all tickers which have less than 200 data-rows.
df_sig_rets = df_sig_rets.groupby(TICKER) \
                .filter(lambda df: len(df)>200)

# List of all unique stock-tickers in the dataset.
tickers = df_sig_rets.reset_index()[TICKER].unique()
# Out:
# Cache-file 'mean_log_change-5cec82bd.pickle' not on disk.
# - Running function mean_log_change() ... Done!
# - Saving cache-file to disk ... Done!

# %% [markdown]
# ### Feature Engineering

# %%
# Split the tickers into training- and test-sets.
tickers_train, tickers_test = \
    train_test_split(tickers, train_size=0.8, random_state=1234)

df_train = df_sig_rets.loc[tickers_train]
df_test = df_sig_rets.loc[tickers_test]

# DataFrames with signals for training- and test-sets.
X_train = df_train.drop(columns=[TOTAL_RETURN_1_3Y])
X_test = df_test.drop(columns=[TOTAL_RETURN_1_3Y])

# DataFrames with stock-returns for training- and test-sets.
y_train = df_train[TOTAL_RETURN_1_3Y]
y_test = df_test[TOTAL_RETURN_1_3Y]

# List of signal names.
signal_names = X_train.columns.values

# List of signal names where spaces are replaced with _
signal_names_ = [s.replace(' ', '_') for s in signal_names]

# Column-name.
FEATURE_IMPORTANCE = 'Feature Importance'

def compare_feature_imp_corr(estimator):
    """
    Return a DataFrame which compares the signals' Feature
    Importance in the Machine Learning model, to the absolute
    correlation of the signals and stock-returns.

    :param estimator: Sklearn ensemble estimator.
    :return: Pandas DataFrame.
    """

    # Wrap the list of Feature Importance in a Pandas Series.
    df_feat_imp = pd.Series(estimator.feature_importances_,
                            index=signal_names,
                            name=FEATURE_IMPORTANCE)

    # Concatenate the DataFrames with Feature Importance
    # and Return Correlation.
    dfs = [df_feat_imp, df_corr_returns]
    df_compare = pd.concat(dfs, axis=1, sort=True)

    # Sort by Feature Importance.
    df_compare.sort_values(by=FEATURE_IMPORTANCE,
                           ascending=False, inplace=True)

    return df_compare

def print_tree(estimator, max_depth=6, **kwargs):
    """
    Print the first Decision Tree from a Random Forest.
    :param estimator: Sklearn ensemble estimator.
    """
    s = export_text(estimator.estimators_[0],
                    max_depth=max_depth,
                    feature_names=signal_names_,
                    **kwargs)
    print(s)

# Parameters for scikit-learn's Random Forest models.
model_args = \
{
    # Random Forest parameters to adjust between
    # over- and under-fitting.
    'n_estimators': 100,
    'max_depth': 15,
    'min_samples_split': 100,
    'min_samples_leaf': 10,

    # Use all available CPU cores.
    'n_jobs': -1,

    # Set random seed to make the experiments repeatable.
    'random_state': 1234,
}

# %% [markdown]
# ### Training 🏋🏿🏋🏿🏋🏿🏋🏿🏋🏿

# %%
# Create the estimator, but don't do any computations yet.
regr = RandomForestRegressor(**model_args)

# Fit the estimator to the training-data.
# This may take several minutes on a 4-core CPU.
_ = regr.fit(X=X_train, y=y_train)

print_tree(regr)
# Out:
# |--- Earnings_Yield <= -0.02
# |   |--- Asset_Turnover <= 0.44
# |   |   |--- P/FCF <= -2.87
# |   |   |   |--- Quick_Ratio <= 5.12
# |   |   |   |   |--- Current_Ratio <= 3.13
# |   |   |   |   |   |--- Return_on_Assets <= -0.23
# |   |   |   |   |   |   |--- Interest_Coverage <= -1.98
# |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- Interest_Coverage >  -1.98
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Return_on_Assets >  -0.23
# |   |   |   |   |   |   |--- Sales_Growth_YOY <= 0.01
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Sales_Growth_YOY >  0.01
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Current_Ratio >  3.13
# |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF <= 0.50
# |   |   |   |   |   |   |--- Assets_Growth_YOY <= 0.32
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Assets_Growth_YOY >  0.32
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF >  0.50
# |   |   |   |   |   |   |--- Asset_Turnover <= 0.32
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Asset_Turnover >  0.32
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |--- Quick_Ratio >  5.12
# |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF <= 0.42
# |   |   |   |   |   |--- Assets_Growth_QOQ <= -0.09
# |   |   |   |   |   |   |--- Sales_Growth <= -0.14
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- Sales_Growth >  -0.14
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- Assets_Growth_QOQ >  -0.09
# |   |   |   |   |   |   |--- Interest_Coverage <= -1.46
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Interest_Coverage >  -1.46
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF >  0.42
# |   |   |   |   |   |--- Earnings_Yield <= -0.06
# |   |   |   |   |   |   |--- FCF_Growth <= -0.71
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- FCF_Growth >  -0.71
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Earnings_Yield >  -0.06
# |   |   |   |   |   |   |--- Sales_Growth <= 0.26
# |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- Sales_Growth >  0.26
# |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |--- P/FCF >  -2.87
# |   |   |   |--- Return_on_Equity <= -0.66
# |   |   |   |   |--- P/NCAV <= -3.44
# |   |   |   |   |   |--- P/Book <= 5.83
# |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |--- P/Book >  5.83
# |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |--- P/NCAV >  -3.44
# |   |   |   |   |   |--- P/NetNet <= 2.64
# |   |   |   |   |   |   |--- Quick_Ratio <= 0.62
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Quick_Ratio >  0.62
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- P/NetNet >  2.64
# |   |   |   |   |   |   |--- FCF_Growth_QOQ <= -0.18
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- FCF_Growth_QOQ >  -0.18
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- Return_on_Equity >  -0.66
# |   |   |   |   |--- Asset_Turnover <= 0.14
# |   |   |   |   |   |--- Sales_Growth_QOQ <= -0.02
# |   |   |   |   |   |   |--- P/Sales <= 0.35
# |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |--- P/Sales >  0.35
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- Sales_Growth_QOQ >  -0.02
# |   |   |   |   |   |   |--- Interest_Coverage <= -6.76
# |   |   |   |   |   |   |   |--- value: [-0.52]
# |   |   |   |   |   |   |--- Interest_Coverage >  -6.76
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Asset_Turnover >  0.14
# |   |   |   |   |   |--- Dividends_/_FCF <= 0.15
# |   |   |   |   |   |   |--- P/NCAV <= -11.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- P/NCAV >  -11.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Dividends_/_FCF >  0.15
# |   |   |   |   |   |   |--- Sales_Growth <= 0.13
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Sales_Growth >  0.13
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |--- Asset_Turnover >  0.44
# |   |   |--- Current_Ratio <= 4.46
# |   |   |   |--- Quick_Ratio <= 0.19
# |   |   |   |   |--- Earnings_Growth_QOQ <= 0.56
# |   |   |   |   |   |--- P/Cash <= 3.89
# |   |   |   |   |   |   |--- P/Book <= -0.03
# |   |   |   |   |   |   |   |--- value: [-0.14]
# |   |   |   |   |   |   |--- P/Book >  -0.03
# |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |--- P/Cash >  3.89
# |   |   |   |   |   |   |--- Assets_Growth_QOQ <= -0.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- Assets_Growth_QOQ >  -0.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |--- Earnings_Growth_QOQ >  0.56
# |   |   |   |   |   |--- Gross_Profit_Margin <= 0.42
# |   |   |   |   |   |   |--- P/NCAV <= -3.88
# |   |   |   |   |   |   |   |--- value: [-0.33]
# |   |   |   |   |   |   |--- P/NCAV >  -3.88
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- Gross_Profit_Margin >  0.42
# |   |   |   |   |   |   |--- value: [-0.28]
# |   |   |   |--- Quick_Ratio >  0.19
# |   |   |   |   |--- Gross_Profit_Margin <= 0.87
# |   |   |   |   |   |--- Log_Revenue <= 8.68
# |   |   |   |   |   |   |--- Asset_Turnover <= 1.95
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Asset_Turnover >  1.95
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Log_Revenue >  8.68
# |   |   |   |   |   |   |--- Log_Revenue <= 10.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Log_Revenue >  10.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Gross_Profit_Margin >  0.87
# |   |   |   |   |   |--- Share_Buyback_/_FCF <= -0.00
# |   |   |   |   |   |   |--- P/Cash <= 18.58
# |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |--- P/Cash >  18.58
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Share_Buyback_/_FCF >  -0.00
# |   |   |   |   |   |   |--- Market-Cap <= 14171166720.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- Market-Cap >  14171166720.00
# |   |   |   |   |   |   |   |--- value: [-0.05]
# |   |   |--- Current_Ratio >  4.46
# |   |   |   |--- Asset_Turnover <= 0.55
# |   |   |   |   |--- Sales_Growth <= 0.46
# |   |   |   |   |   |--- P/Cash <= 8.56
# |   |   |   |   |   |   |--- Assets_Growth <= 0.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- Assets_Growth >  0.07
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- P/Cash >  8.56
# |   |   |   |   |   |   |--- FCF_Growth_QOQ <= -0.44
# |   |   |   |   |   |   |   |--- value: [-0.12]
# |   |   |   |   |   |   |--- FCF_Growth_QOQ >  -0.44
# |   |   |   |   |   |   |   |--- value: [-0.52]
# |   |   |   |   |--- Sales_Growth >  0.46
# |   |   |   |   |   |--- Earnings_Growth_QOQ <= -0.11
# |   |   |   |   |   |   |--- Net_Profit_Margin <= -0.13
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- Net_Profit_Margin >  -0.13
# |   |   |   |   |   |   |   |--- value: [-0.30]
# |   |   |   |   |   |--- Earnings_Growth_QOQ >  -0.11
# |   |   |   |   |   |   |--- FCF_Growth <= -0.11
# |   |   |   |   |   |   |   |--- value: [-0.25]
# |   |   |   |   |   |   |--- FCF_Growth >  -0.11
# |   |   |   |   |   |   |   |--- value: [-0.52]
# |   |   |   |--- Asset_Turnover >  0.55
# |   |   |   |   |--- Asset_Turnover <= 1.23
# |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) <= 1.34
# |   |   |   |   |   |   |--- P/NCAV <= 7.47
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- P/NCAV >  7.47
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) >  1.34
# |   |   |   |   |   |   |--- FCF_Growth <= 1.16
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- FCF_Growth >  1.16
# |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |--- Asset_Turnover >  1.23
# |   |   |   |   |   |--- Gross_Profit_Margin <= 0.29
# |   |   |   |   |   |   |--- Interest_Coverage <= 22.64
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- Interest_Coverage >  22.64
# |   |   |   |   |   |   |   |--- value: [-0.34]
# |   |   |   |   |   |--- Gross_Profit_Margin >  0.29
# |   |   |   |   |   |   |--- P/NetNet <= 1.35
# |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |--- P/NetNet >  1.35
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |--- Earnings_Yield >  -0.02
# |   |--- P/FCF <= 5.52
# |   |   |--- Current_Ratio <= 4.38
# |   |   |   |--- Share_Buyback_/_FCF <= 0.06
# |   |   |   |   |--- Earnings_Yield <= 0.04
# |   |   |   |   |   |--- Asset_Turnover <= 0.24
# |   |   |   |   |   |   |--- Current_Ratio <= 1.27
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Current_Ratio >  1.27
# |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- Asset_Turnover >  0.24
# |   |   |   |   |   |   |--- Quick_Ratio <= 0.52
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Quick_Ratio >  0.52
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Earnings_Yield >  0.04
# |   |   |   |   |   |--- Log_Revenue <= 8.25
# |   |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF <= 0.28
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF >  0.28
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- Log_Revenue >  8.25
# |   |   |   |   |   |   |--- Market-Cap <= 481139616.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Market-Cap >  481139616.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |--- Share_Buyback_/_FCF >  0.06
# |   |   |   |   |--- P/Book <= 10.08
# |   |   |   |   |   |--- Log_Revenue <= 8.23
# |   |   |   |   |   |   |--- P/Cash <= 66.13
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- P/Cash >  66.13
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- Log_Revenue >  8.23
# |   |   |   |   |   |   |--- Assets_Growth <= 0.68
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Assets_Growth >  0.68
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- P/Book >  10.08
# |   |   |   |   |   |--- P/NCAV <= 35.63
# |   |   |   |   |   |   |--- Sales_Growth <= 0.10
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- Sales_Growth >  0.10
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- P/NCAV >  35.63
# |   |   |   |   |   |   |--- value: [-0.29]
# |   |   |--- Current_Ratio >  4.38
# |   |   |   |--- Log_Revenue <= 8.45
# |   |   |   |   |--- P/Cash <= 5.69
# |   |   |   |   |   |--- Gross_Profit_Margin <= 0.36
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) <= 0.69
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) >  0.69
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- Gross_Profit_Margin >  0.36
# |   |   |   |   |   |   |--- P/E <= 1.63
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- P/E >  1.63
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |--- P/Cash >  5.69
# |   |   |   |   |   |--- P/NCAV <= -1.94
# |   |   |   |   |   |   |--- Market-Cap <= 115107068.00
# |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |--- Market-Cap >  115107068.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- P/NCAV >  -1.94
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) <= 1.83
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) >  1.83
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- Log_Revenue >  8.45
# |   |   |   |   |--- FCF_Growth_YOY <= -2.63
# |   |   |   |   |   |--- Market-Cap <= 1517324032.00
# |   |   |   |   |   |   |--- value: [-0.52]
# |   |   |   |   |   |--- Market-Cap >  1517324032.00
# |   |   |   |   |   |   |--- P/Book <= 1.96
# |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |--- P/Book >  1.96
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- FCF_Growth_YOY >  -2.63
# |   |   |   |   |   |--- P/Book <= 13.71
# |   |   |   |   |   |   |--- Sales_Growth_YOY <= 0.29
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Sales_Growth_YOY >  0.29
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- P/Book >  13.71
# |   |   |   |   |   |   |--- P/Cash <= 86.97
# |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- P/Cash >  86.97
# |   |   |   |   |   |   |   |--- value: [0.24]
# |   |--- P/FCF >  5.52
# |   |   |--- CapEx_/_(Depr_+_Amor) <= 1.22
# |   |   |   |--- Share_Buyback_/_FCF <= 0.01
# |   |   |   |   |--- Sales_Growth <= 0.53
# |   |   |   |   |   |--- FCF_Growth_QOQ <= -0.89
# |   |   |   |   |   |   |--- Market-Cap <= 2300775168.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Market-Cap >  2300775168.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- FCF_Growth_QOQ >  -0.89
# |   |   |   |   |   |   |--- Asset_Turnover <= 2.14
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Asset_Turnover >  2.14
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Sales_Growth >  0.53
# |   |   |   |   |   |--- Dividends_/_FCF <= 0.00
# |   |   |   |   |   |   |--- P/E <= 10.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- P/E >  10.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Dividends_/_FCF >  0.00
# |   |   |   |   |   |   |--- P/Book <= 6.62
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- P/Book >  6.62
# |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- Share_Buyback_/_FCF >  0.01
# |   |   |   |   |--- Asset_Turnover <= 2.08
# |   |   |   |   |   |--- Sales_Growth <= 0.52
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) <= 0.19
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- CapEx_/_(Depr_+_Amor) >  0.19
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Sales_Growth >  0.52
# |   |   |   |   |   |   |--- Log_Revenue <= 9.54
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Log_Revenue >  9.54
# |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |--- Asset_Turnover >  2.08
# |   |   |   |   |   |--- Interest_Coverage <= 32.88
# |   |   |   |   |   |   |--- Earnings_Yield <= 0.05
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Earnings_Yield >  0.05
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Interest_Coverage >  32.88
# |   |   |   |   |   |   |--- Quick_Ratio <= 1.12
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Quick_Ratio >  1.12
# |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |--- CapEx_/_(Depr_+_Amor) >  1.22
# |   |   |   |--- Asset_Turnover <= 0.47
# |   |   |   |   |--- P/NCAV <= -1.52
# |   |   |   |   |   |--- Market-Cap <= 3530597888.00
# |   |   |   |   |   |   |--- Interest_Coverage <= 11.39
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Interest_Coverage >  11.39
# |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |--- Market-Cap >  3530597888.00
# |   |   |   |   |   |   |--- Gross_Profit_Margin <= 0.84
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Gross_Profit_Margin >  0.84
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- P/NCAV >  -1.52
# |   |   |   |   |   |--- Asset_Turnover <= 0.44
# |   |   |   |   |   |   |--- Share_Buyback_/_FCF <= 0.43
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Share_Buyback_/_FCF >  0.43
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Asset_Turnover >  0.44
# |   |   |   |   |   |   |--- Dividends_/_FCF <= 0.05
# |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- Dividends_/_FCF >  0.05
# |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |--- Asset_Turnover >  0.47
# |   |   |   |   |--- Gross_Profit_Margin <= 0.28
# |   |   |   |   |   |--- Log_Revenue <= 9.22
# |   |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF <= -0.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- (Dividends_+_Share_Buyback)_/_FCF >  -0.03
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Log_Revenue >  9.22
# |   |   |   |   |   |   |--- P/Cash <= 4.93
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- P/Cash >  4.93
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- Gross_Profit_Margin >  0.28
# |   |   |   |   |   |--- Asset_Turnover <= 1.91
# |   |   |   |   |   |   |--- Market-Cap <= 76989760.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Market-Cap >  76989760.00
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- Asset_Turnover >  1.91
# |   |   |   |   |   |   |--- Log_Revenue <= 9.27
# |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Log_Revenue >  9.27
# |   |   |   |   |   |   |   |--- truncated branch of depth 9

# %% [markdown]
# ### Testing 💯💯💯💯💯
