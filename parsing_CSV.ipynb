# %%
import pandas as pd
import csv

df = pd.read_csv('TOTAL_US_STOCK_MARKET_CLEAN.csv')
df.head()
# Out:
#    index ticker                         name                finnhubIndustry  \
# 0      0   AACG        ATA Creativity Global  Diversified Consumer Services
# 1      1    AAL  American Airlines Group Inc                       Airlines
# 2      2   AAME       Atlantic American Corp                      Insurance
# 3      3   AAOI  Applied Optoelectronics Inc                 Communications
# 4      4   AAON                     Aaon Inc                       Building
#
#   country currency                    exchange        ipo  \
# 0      CN      USD  NASDAQ NMS - GLOBAL MARKET  1/29/2008
# 1      US      USD  NASDAQ NMS - GLOBAL MARKET  12/9/2013
# 2      US      USD  NASDAQ NMS - GLOBAL MARKET  1/16/1980
# 3      US      USD  NASDAQ NMS - GLOBAL MARKET  9/26/2013
# 4      US      USD  NASDAQ NMS - GLOBAL MARKET   1/3/1991
#
#   marketCapitalization marketCapClass shareOutstanding
# 0             27.29185      MICRO_CAP        56.626346
# 1             7844.693        MID_CAP       422.894501
# 2             36.78906      MICRO_CAP        20.438366
# 3             197.1919      MICRO_CAP        20.339549
# 4             2980.886        MID_CAP        52.031532

# %% [markdown]
# # Segmentation
# #### Creates a nested dictionary for each segment of the CSV
# ##### Market Cap -> Industry

# %%
# View the various categories
print('MARKET CAP: ', df.marketCapClass.unique())
print('INDUSTRIES: ', df.finnhubIndustry.unique())

# %%
d = {}
for marketCap in df.marketCapClass.unique():
    if marketCap == 'marketCapClass':
        continue
    d[marketCap] = {}
    for industry in df.finnhubIndustry.unique():
        if industry == 'finnhubIndustry':
            continue
        d[marketCap][industry] = list()

# %%
for ticker, data in df.iterrows():
    # Throw away headers
    if data['marketCapClass'] == 'marketCapClass':
        continue
    if data['finnhubIndustry'] == 'finnhubIndustry':
        continue
    # Create dictionary
    d[data['marketCapClass']][data['finnhubIndustry']].append(data['ticker'])
d
# Out:
# {'MICRO_CAP': {'Diversified Consumer Services': ['AACG',
#    'ASPU',
#    'CLCT',
#    'DCAR',
#    'HYRE',
#    'LINC',
#    'REDU',
#    'SIC',
#    'TEDU',
#    'WAFU',
#    'XSPA',
#    'ZVO',
#    'DAO',
#    'DL',
#    'FEDU',
#    'LAIX',
#    'RYB',
#    'STG',
#    'STON',
#    'UTI',
#    'AMBO'],
#   'Airlines': ['MESA'],
#   'Insurance': ['AAME',
#    'AFH',
#    'CNFR',
#    'FNHC',
#    'GLRE',
#    'HALL',
#    'ICCH',
#    'ITIC',
#    'KINS',
#    'MHLD',
#    'NSEC',
#    'OXBR',
#    'PIH',
#    'PPHI',
#    'PTVCB',
#    'TIPT',
#    'UNAM',
#    'VERY',
#    'AMBC',
#    'KFS'],
#   'Communications': ['AAOI',
#    'AVNW',
#    'BOSC',
#    'CAMP',
#    'CLFD',
#    'CLRO',
#    'CMBM',
#    'CRNT',
#    'DZSI',
#    'EMKR',
#    'EXF.TO',
#    'JCS',
#    'KVHI',
#    'LTRX',
#    'OCC',
#    'PCTI',
#    'RDCM',
#    'RESN',
#    'SILC',
#    'TCCO',
#    'TESS',
#    'UTSI',
#    'VISL',
#    'WSTL',
#    'BDR',
#    'BKTI',
#    'NTIP'],
#   'Building': ['CCCL', 'DRT.TO', 'JCTCF', 'TGEN', 'AFI', 'APT'],
#   'Technology': ['AEYE',
#    'ALJJ',
#    'ALLT',
#    'ALOT',
#    'ALYA.TO',
#    'AMRH',
#    'ANY',
#    'ASUR',
#    'AWRE',
#    'BKYI',
#    'BLIN',
#    'BOXL',
#    'BRQS',
#    'BSQR',
#    'CLPS',
#    'CPAH',
#    'CSPI',
#    'CTG',
#    'CYRN',
#    'DMRC',
#    'DTSS',
#    'EVOL',
#    'FNJN',
#    'GSUM',
#    'GTYH',
#    'GVP',
#    'IDEX',
#    'III',
#    'IMMR',
#    'INOD',
#    'INPX',
#    'IVAC',
#    'JG',
#    'MARA',
#    'MGI',
#    'MNDO',
#    'MRIN',
#    'MTC',
#    'MTSL',
#    'MYSZ',
#    'NETE',
#    'NTWK',
#    'NXTD',
#    'OSS',
#    'PBTS',
#    'PCYG',
#    'PFSW',
#    'PHUN',
#    'PRGX',
#    'PRTH',
#    'QMCO',
#    'QUMU',
#    'RIOT',
#    'RNWK',
#    'RSSS',
#    'SCKT',
#    'SEAC',
#    'SHSP',
#    'SMSI',
#    'SNCR',
#    'SONM',
#    'SPRT',
#    'SREV',
#    'SSNT',
#    'SSTI',
#    'STCN',
#    'SYNC',
#    'TACT',
#    'TAOP',
#    'TNAV',
#    'TSRI',
#    'UEPS',
#    'USIO',
#    'VERB',
#    'XELA',
#    'XNET',
#    'KODK',
#    'SRT',
#    'GSB',
#    'INUV',
#    'ISDR',
#    'WYY'],
#   'Logistics & Transportation': ['AIRT', 'RLGT'],
#   'Aerospace & Defense': ['ASTC',
#    'ISSC',
#    'MICT',
#    'RADA',
#    'SGLB',
#    'TATT',
#    'VTSI',
#    'PKE',
#    'AIRI',
#    'CVU',
#    'SIF'],
#   'Banking': ['ACBI',
#    'ACNB',
#    'AMRB',
#    'ASRV',
#    'ATLO',
#    'AUBN',
#    'BCBP',
#    'BCML',
#    'BFIN',
#    'BKSC',
#    'BOCH',
#    'BOTJ',
#    'BPRN',
#    'BSVN',
#    'BWFG',
#    'CALB',
#    'CARE',
#    'CBAN',
#    'CBFV',
#    'CBNK',
#    'CCB',
#    'CFBI',
#    'CFFI',
#    'CHMG',
#    'CIVB',
#    'CIZN',
#    'CLDB',
#    'CNBKA',
#    'COFS',
#    'CSTR',
#    'CVCY',
#    'CVLY',
#    'CWBC',
#    'CZNC',
#    'CZWI',
#    'DBCP',
#    'EBMT',
#    'EBTC',
#    'EMCF',
#    'EQBK',
#    'ESQ',
#    'ESXB',
#    'FBIZ',
#    'FBSS',
#    'FCAP',
#    'FCBP',
#    'FCCO',
#    'FCCY',
#    'FDBC',
#    'FFNW',
#    'FGBI',
#    'FMAO',
#    'FNCB',
#    'FNLC',
#    'FNWB',
#    'FRAF',
#    'FRBA',
#    'FRBK',
#    'FSFG',
#    'FUNC',
#    'FUSB',
#    'FVCB',
#    'FXNC',
#    'GLBZ',
#    'HBMD',
#    'HTBI',
#    'HWBK',
#    'ICBK',
#    'INBK',
#    'ISTR',
#    'LARK',
#    'LCNB',
#    'LEVL',
#    'LMST',
#    'MBCN',
#    'MCBC',
#    'MFNC',
#    'MLVF',
#    'MNSB',
#    'MPB',
#    'MRBK',
#    'MVBF',
#    'MYFW',
#    'NBN',
#    'NKSH',
#    'NRIM',
#    'NWFL',
#    'OPHC',
#    'OPOF',
#    'ORRF',
#    'OSBC',
#    'OVBC',
#    'OVLY',
#    'PBHC',
#    'PCB',
#    'PEBK',
#    'PFBI',
#    'PFIS',
#    'PKBK',
#    'PLBC',
#    'PMBC',
#    'PNBK',
#    'PWOD',
#    'RBB',
#    'RBNC',
#    'RIVE',
#    'RMBI',
#    'RRBI',
#    'SAL',
#    'SBBX',
#    'SBFG',
#    'SFBC',
#    'SFST',
#    'SHBI',
#    'SLCT',
#    'SMBK',
#    'SMMF',
#    'SONA',
#    'SPFI',
#    'SSBI',
#    'STXB',
#    'TCFC',
#    'UBCP',
#    'UBFO',
#    'UBOH',
#    'UNB',
#    'UNTY',
#    'VBFC',
#    'WEBK',
#    'MCB',
#    'SI',
#    'TFC',
#    'EVBN'],
#   'Biotechnology': ['ABEO',
#    'ABIO',
#    'ABUS',
#    'ACHV',
#    'ACOR',
#    'ADMA',
#    'ADMS',
#    'ADRO',
#    'ADXS',
#    'AEZS.TO',
#    'AFMD',
#    'AGTC',
#    'ALDX',
#    'ALNA',
#    'ALPN',
#    'ALRN',
#    'ALT',
#    'AMAG',
#    'ANIX',
#    'APM',
#    'APTX',
#    'APVO',
#    'AQB',
#    'ARAV',
#    'ARDS',
#    'AVEO',
#    'AVXL',
#    'AXGT',
#    'AXLA',
#    'AZRX',
#    'BBI',
#    'BCDA',
#    'BCLI',
#    'BIOC',
#    'BLCM',
#    'BPTH',
#    'CABA',
#    'CAPR',
#    'CASI',
#    'CATB',
#    'CBIO',
#    'CBLI',
#    'CBMG',
#    'CDTX',
#    'CELC',
#    'CFRX',
#    'CGIX',
#    'CKPT',
#    'CLBS',
#    'CLDX',
#    'CLRB',
#    'CLSN',
#    'CLXT',
#    'CMRX',
#    'CNAT',
#    'CNCE',
#    'CRDF',
#    'CRIS',
#    'CRVS',
#    'CTIC',
#    'CWBR',
#    'CYCC',
#    'CYCN',
#    'DFFN',
#    'DMAC',
#    'DMPI',
#    'DMTK',
#    'DYAI',
#    'EDSA',
#    'EIGR',
#    'ENLV',
#    'ENOB',
#    'ENTX',
#    'EPI.V',
#    'EQ',
#    'ETTX',
#    'EVGN.TA',
#    'EVLO',
#    'FBIO',
#    'FENC',
#    'FPRX',
#    'FWP',
#    'GALT',
#    'GLMD',
#    'GLYC',
#    'GMDA',
#    'GNCA',
#    'GNPX',
#    'GRTS',
#    'GRTX',
#    'HTBX',
#    'ICCC',
#    'IDRA',
#    'IDYA',
#    'IFRX',
#    'IMUX',
#    'IMV.TO',
#    'INFI',
#    'INMB',
#    'ISEE',
#    'JNCE',
#    'KALV',
#    'KIN',
#    'KZR',
#    'LIFE',
#    'LJPC',
#    'LOGC',
#    'LPTX',
#    'LXRX',
#    'MACK',
#    'MBIO',
#    'MBRX',
#    'MGEN',
#    'MITO',
#    'MLND',
#    'MNOV',
#    'MNPR',
#    'MRKR',
#    'NCNA',
#    'NERV',
#    'NRBO',
#    'NTEC',
#    'NTRP',
#    'NYMX',
#    'OBSV',
#    'OCGN',
#    'ONCS',
#    'ONCT',
#    'ONC.TO',
#    'ONVO',
#    'OPGN',
#    'ORGS',
#    'OTLK',
#    'OVID',
#    'PDSB',
#    'PHAS',
#    'PHIO',
#    'PIRS',
#    'PRQR',
#    'PSTI',
#    'PSTV',
#    'PTE',
#    'PTI',
#    'REXN',
#    'RGLS',
#    'SBPH',
#    'SESN',
#    'SLDB',
#    'SLNO',
#    'SLRX',
#    'SLS',
#    'SNCA',
#    'SNGX',
#    'SNSS',
#    'SPRO',
#    'SRRA',
#    'SURF',
#    'SVRA',
#    'SYBX',
#    'TARA',
#    'TCON',
#    'TENX',
#    'TH.TO',
#    'TNXP',
#    'TOCA',
#    'TRVN',
#    'TTOO',
#    'TYME',
#    'UMRX',
#    'VBLT',
#    'VCNX',
#    'VTGN',
#    'VTVT',
#    'VXRT',
#    'WINT',
#    'XBIO',
#    'XCUR',
#    'XFOR',
#    'XOMA',
#    'YTEN',
#    'ZFGN',
#    'AGE',
#    'AIM',
#    'ARMP',
#    'ATNM',
#    'IBIO',
#    'ISR',
#    'LCTX',
#    'MTNB',
#    'NAVB',
#    'NNVC',
#    'OCX',
#    'OGEN',
#    'PLX',
#    'PTN',
#    'SYN'],
#   'Health Care': ['AEMD',
#    'AHPI',
#    'AIH',
#    'AKER',
#    'APEN',
#    'APYX',
#    'ARAY',
#    'ATOS',
#    'AVCO',
#    'AVGR',
#    'BIOL',
#    'BLPH',
#    'BMRA',
#    'CCRN',
#    'CEMI',
#    'CFMS',
#    'CHEK',
#    'CHFS',
#    'CUTR',
#    'DARE',
#    'DCTH',
#    'DRAD',
#    'DRIO',
#    'DYNT',
#    'ECOR',
#    'EDAP',
#    'EKSO',
#    'ELGX',
#    'EYES',
#    'FONR',
#    'FVE',
#    'HJLI',
#    'HSDT',
#    'HTGM',
#    'ICAD',
#    'IDXG',
#    'IIN',
#    'IMAC',
#    'IRIX',
#    'IRMD',
#    'JYNT',
#    'KEQU',
#    'LLIT',
#    'MBOT',
#    'MOTS',
#    'MSON',
#    'MTBC',
#    'NAOV',
#    'NDRA',
#    'NMRD',
#    'NURO',
#    'NVCN.TO',
#    'NVIV',
#    'OBLN',
#    'OPRX',
#    'PAVM',
#    'PDEX',
#    'PLSE',
#    'PMD',
#    'POAI',
#    'PRN.TO',
#    'PRPO',
#    'RTIX',
#    'RWLK',
#    'SIEN',
#    'SINT',
#    'SMED',
#    'SOLY',
#    'SRTS',
#    'SSKN',
#    'STIM',
#    'STRM',
#    'TELA',
#    'THMO',
#    'TMD.TO',
#    'TRIB',
#    'VERO',
#    'VIVE',
#    'XAIR',
#    'XGN',
#    'ZSAN',
#    'ARA',
#    'CCM',
#    'CNMD',
#    'CSLT',
#    'CSU',
#    'ENZ',
#    'GEN',
#    'IVC',
#    'RMED',
#    'AMS',
#    'CRH.TO',
#    'CTEK',
#    'DXR',
#    'ELMD',
#    'INFU',
#    'MLSS',
#    'MYO',
#    'NSPR',
#    'RHE',
#    'RVP',
#    'SENS',
#    'SSY',
#    'TRXC',
#    'VNRX',
#    'XTNT'],
#   'Pharmaceuticals': ['ACER',
#    'ACRS',
#    'ACRX',
#    'ACST.V',
#    'ADIL',
#    'ADMP',
#    'AGRX',
#    'AKRX',
#    'AKTX',
#    'ALIM',
#    'AQST',
#    'ARPO',
#    'ARTL',
#    'ASRT',
#    'ATXI',
#    'AYTU',
#    'BVXV',
#    'BXRX',
#    'CBAY',
#    'CERC',
#    'CHMA',
#    'CLSD',
#    'CNSP',
#    'COCP',
#    'CORV.TO',
#    'CPIX',
#    'CTXR',
#    'EARS',
#    'ELOX',
#    'EOLS',
#    'ETON',
#    'EVFM',
#    'EVOK',
#    'EYEG',
#    'EYEN',
#    'EYPT',
#    'HEPA',
#    'HOTH',
#    'HROW',
#    'HUGE.CN',
#    'ITRM',
#    'JAGX',
#    'KLDO',
#    'LPCN',
#    'LQDA',
#    'MDWD',
#    'MIST',
#    'MRNS',
#    'NBRV',
#    'NEOS',
#    'NOVN',
#    'NVUS',
#    'ONTX',
#    'OPNT',
#    'OPTN',
#    'ORMP',
#    'OTIC',
#    'PLXP',
#    'PRPH',
#    'PRTK',
#    'PULM',
#    'REPH',
#    'RTTR',
#    'SAVA',
#    'SBBP',
#    'SCPH',
#    'SCYX',
#    'SEEL',
#    'SLGL',
#    'SNDL',
#    'SNES',
#    'SNOA',
#    'TFFP',
#    'TLGT',
#    'TORC',
#    'TRVI',
#    'TTNP',
#    'TTPH',
#    'VVUS',
#    'XERS',
#    'ZYNE',
#    'MNK',
#    'AMPE',
#    'CPHI',
#    'CRMD',
#    'NBY',
#    'YCBD',
#    'ZOM'],
#   'Semiconductors': ['AEHR',
#    'ASYS',
#    'ATOM',
#    'AXTI',
#    'CVV',
#    'CYBE',
#    'EVSI',
#    'GSIT',
#    'KOPN',
#    'LEDS',
#    'MOSY',
#    'MRAM',
#    'OIIM',
#    'PXLW',
#    'QUIK',
#    'RBCN',
#    'SPI',
#    'WISA',
#    'SQNS',
#    'EMAN',
#    'INTT',
#    'TRT'],
#   'Professional Services': ['ACTG',
#    'ATIF',
#    'CIH',
#    'DLHC',
#    'HHR',
#    'HQI',
#    'HSON',
#    'INWK',
#    'KERN',
#    'LTBR',
#    'PIXY',
#    'RCMT',
#    'RDVT',
#    'REKR',
#    'STAF',
#    'BGSF',
#    'GPX',
#    'HIL',
#    'MG',
#    'JOB',
#    'MHH',
#    'VOLT'],
#   'Chemicals': ['ADES',
#    'AGFS',
#    'FFHL',
#    'GURE',
#    'IKNX',
#    'MBII',
#    'MX.TO',
#    'NTIC',
#    'TANH',
#    'CGA',
#    'CINR',
#    'FTK',
#    'IPI',
#    'LXU',
#    'RYAM',
#    'TREC',
#    'UAN',
#    'VNTR',
#    'CMT',
#    'FSI'],
#   'Life Sciences Tools & Services': ['BASI',
#    'BNGO',
#    'CDXC',
#    'CSBR',
#    'FLDM',
#    'HBIO'],
#   'Construction': ['BBCP',
#    'HHT',
#    'IEA',
#    'LMB',
#    'NWPX',
#    'PECK',
#    'RETO',
#    'TGLS',
#    'HCHC',
#    'ORN',
#    'SOL',
#    'GV'],
#   'Hotels, Restaurants & Leisure': ['AESE',
#    'ARKR',
#    'BBQ',
#    'CLUB',
#    'CNTY',
#    'CPHC',
#    'FAT',
#    'FLL',
#    'FRGI',
#    'GMBL',
#    'GTIM',
#    'INSE',
#    'KRUS',
#    'NATH',
#    'NDLS',
#    'NWGI',
#    'PBPB',
#    'RAVE',
#    'RICK',
#    'RRGB',
#    'STKS',
#    'TACO',
#    'TAST',
#    'TOUR',
#    'AGS',
#    'BBX',
#    'BH',
#    'DS',
#    'DVD',
#    'JAX',
#    'LUB',
#    'RLH',
#    'WBAI',
#    'BDL',
#    'BWL.A'],
#   'Electrical Equipment': ['AEY',
#    'AIRG',
#    'AMSC',
#    'APDN',
#    'APWC',
#    'BELFA',
#    'BNSO',
#    'BWEN',
#    'CBAT',
#    'CETX',
#    'CLIR',
#    'CODA',
#    'CPSH',
#    'CPST',
#    'DAIO',
#    'DAKT',
#    'DGLY',
#    'DSWL',
#    'EFOI',
#    'ELSE',
#    'ELTK',
#    'FEIM',
#    'GNSS',
#    'IDN',
#    'IEC',
#    'IMTE',
#    'INVE',
#    'IPWR',
#    'ISNS',
#    'ITI',
#    'KTCC',
#    'LPTH',
#    'LUNA',
#    'LYTS',
#    'MAGS',
#    'MVIS',
#    'NEON',
#    'NSYS',
#    'OEG',
#    'OESX',
#    'OPTT',
#    'PLPC',
#    'POLA',
#    'PPSI',
#    'PRCP',
#    'PWFL',
#    'REFR',
#    'RELL',
#    'RFIL',
#    'SCON',
#    'SGMA',
#    'SGOC',
#    'SMIT',
#    'SMTX',
#    'SPCB',
#    'SUNW',
#    'TAIT',
#    'ULBI',
#    'VRME',
#    'WATT',
#    'WRTC',
#    'WSTG',
#    'ARLO',
#    'BW',
#    'DPW',
#    'ESP',
#    'LGL',
#    'SVT',
#    'UUU',
#    'WTT'],
#   'Real Estate': ['ASPS',
#    'CMCT',
#    'GRIF',
#    'GYRO',
#    'HGSH',
#    'INTG',
#    'LMRK',
#    'LOAN',
#    'MAYS',
#    'MDJH',
#    'MDRR',
#    'OBAS.TA',
#    'SELF',
#    'SOHO',
#    'STRS',
#    'TRMT',
#    'WHLR',
#    'AHT',
#    'AI',
#    'AJX',
#    'ANH',
#    'ARL',
#    'BHR',
#    'BRT',
#    'CBL',
#    'CDR',
#    'CHMI',
#    'CLPR',
#    'CORR',
#    'CPLG',
#    'EARN',
#    'FPI',
#    'HCFT',
#    'MITT',
#    'MLP',
#    'NTP',
#    'PEI',
#    'PLYM',
#    'PSTL',
#    'RFL',
#    'TCI',
#    'WMC',
#    'WPG',
#    'XAN',
#    'XIN',
#    'AAMC',
#    'BRG',
#    'CDOR',
#    'CDOR',
#    'CKX',
#    'CTO',
#    'HMG',
#    'IHT',
#    'NEN',
#    'PW',
#    'TPHS'],
#   'Financial Services': ['AIHS',
#    'AMRK',
#    'ASFI',
#    'ATAX',
#    'ATLC',
#    'BANX',
#    'BCOW',
#    'BCTF',
#    'BKCC',
#    'BSBK',
#    'BYFC',
#    'CARV',
#    'CBMB',
#    'CFBK',
#    'CPSS',
#    'CPTA',
#    'CSWC',
#    'DNJR',
#    'ESBK',
#    'ESSA',
#    'FDUS',
#    'FFBW',
#    'FPAY',
#    'FSBW',
#    'FSEA',
#    'GARS',
#    'GCBC',
#    'GEC',
#    'GECC',
#    'GFED',
#    'GLAD',
#    'GRNQ',
#    'GROW',
#    'GWGH',
#    'HBCP',
#    'HCAP',
#    'HFBL',
#    'HMNF',
#    'HNNA',
#    'HRZN',
#    'HUSN',
#    'HVBC',
#    'HX',
#    'ICMB',
#    'IROQ',
#    'JFIN',
#    'JRJC',
#    'KFFB',
#    'LMFA',
#    'LSBK',
#    'LYL',
#    'MFIN',
#    'MGYR',
#    'MMAC',
#    'MOGO.TO',
#    'MRCC',
#    'MRLN',
#    'MSBF',
#    'MSVB',
#    'NHLD',
#    'NICK',
#    'OCSI',
#    'OFED',
#    'OFS',
#    'OPBK',
#    'OTTW',
#    'OXSQ',
#    'PBFS',
#    'PBIP',
#    'PCSB',
#    'PDLB',
#    'PHCF',
#    'PNNT',
#    'PROV',
#    'PT',
#    'PTMN',
#    'PVBC',
#    'RAND',
#    'RBKB',
#    'RNDB',
#    'RVSB',
#    'SAMG',
#    'SBT',
#    'SIEB',
#    'SMBC',
#    'SNFCA',
#    'SSSS',
#    'STND',
#    'SUNS',
#    'SVBI',
#    'SVVC',
#    'SWKH',
#    'TBNK',
#    'TCRD',
#    'TSBK',
#    'TURN',
#    'VALU',
#    'WHF',
#    'WINS',
#    'WNEB',
#    'WVFC',
#    'CNF',
#    'ELVT',
#    'EQS',
#    'GCAP',
#    'GHL',
#    'JMP',
#    'JP',
#    'JT',
#    'MCC',
#    'MDLY',
#    'MN',
#    'MVC',
#    'OCN',
#    'ONDK',
#    'RM',
#    'SAR',
#    'SCM',
#    'SFE',
#    'SOR',
#    'SRL',
#    'WEI',
#    'WHG',
#    'XRF',
#    'XYF',
#    'AINC',
#    'COHN',
#    'DXF',
#    'IMH',
#    'IOR',
#    'RCG',
#    'SACH'],
#   'Machinery': ['ARTW',
#    'BIMI',
#    'CVGI',
#    'EML',
#    'FSTR',
#    'GENC',
#    'GTEC',
#    'HEBT',
#    'HIHO',
#    'HURC',
#    'LIQT',
#    'MNTX',
#    'NEWA',
#    'NNBR',
#    'PKOH',
#    'PPIH',
#    'RAIL',
#    'SGBX',
#    'TAYD',
#    'TWIN',
#    'WPRT.TO',
#    'XONE',
#    'BGG',
#    'GHM',
#    'SCX',
#    'TWI',
#    'VJET',
#    'CVR',
#    'KLS.TO',
#    'UAVS'],
#   'Food Products': ['ALCO',
#    'BRID',
#    'FAMI',
#    'FARM',
#    'FTFT',
#    'JVA',
#    'LMNR',
#    'LWAY',
#    'PETZ',
#    'PLIN',
#    'PME',
#    'RIBT',
#    'RKDA',
#    'RMCF',
#    'SANW',
#    'SEED',
#    'RYCE',
#    'BIOX',
#    'PLAG'],
#   'Telecommunication': ['ALSK',
#    'GOGO',
#    'OTEL',
#    'SIFY',
#    'SPOK',
#    'TEUM',
#    'CEL.TA',
#    'CEL.TA',
#    'IDT'],
#   'Energy ': ['AMTX',
#    'AREC',
#    'AXAS',
#    'BKEP',
#    'CLMT',
#    'CPLP',
#    'EPSN',
#    'GASS',
#    'GEVO',
#    'GMLP',
#    'GPP',
#    'HNRG',
#    'LONE',
#    'MARPS',
#    'MCEP',
#    'MMLP',
#    'NEXT',
#    'PEIX',
#    'PNRG',
#    'PVAC',
#    'ROSE',
#    'SNDE',
#    'TGL.TO',
#    'TOPS',
#    'TRCH',
#    'USEG',
#    'VTNR',
#    'WWR',
#    'XOG',
#    'ZN',
#    'AMPY',
#    'ASC',
#    'BPT',
#    'CCR',
#    'CEIX',
#    'CHAP',
#    'CHK',
#    'CRC',
#    'CRT',
#    'CTRA',
#    'DLNG',
#    'DNR',
#    'ECT',
#    'EGY',
#    'ESTE',
#    'GLOP',
#    'HPR',
#    'MR',
#    'MTR',
#    'MVO',
#    'NC',
#    'NNA',
#    'NRP',
#    'NRT',
#    'OSG',
#    'OVV.TO',
#    'PBT',
#    'PER',
#    'PHX',
#    'PRT',
#    'PVL',
#    'ROYT',
#    'SBOW',
#    'SD',
#    'SJT',
#    'SMLP',
#    'TNP',
#    'UNT',
#    'USDP',
#    'VOC',
#    'WLL',
#    'AE',
#    'BRN',
#    'CEI',
#    'EPM',
#    'GBR',
#    'GDP',
#    'GTE',
#    'HUSA',
#    'INDO',
#    'LEU',
#    'LLEX',
#    'MXC',
#    'PED',
#    'REI',
#    'SNMP',
#    'TAT',
#    'TGC',
#    'UEC',
#    'URE.TO',
#    'EFR.TO'],
#   'Media': ['ANTE',
#    'AUTO',
#    'BBGI',
#    'BHAT',
#    'CIDM',
#    'CMLS',
#    'CNET',
#    'CREX',
#    'CSSE',
#    'DLPN',
#    'ENT',
#    'FLNT',
#    'GAIA',
#    'GIGM',
#    'ISIG',
#    'IZEA',
#    'KRKR',
#    'LIVX',
#    'LKCO',
#    'MCHX',
#    'MDCA',
#    'NCMI',
#    'NCTY',
#    'PERI',
#    'RDI',
#    'SALM',
#    'SCOR',
#    'SGA',
#    'SGRP',
#    'SLGG',
#    'SRAX',
#    'TC',
#    'TZOO',
#    'UONEK',
#    'YVR',
#    'AHC',
#    'DHX',
#    'EEX',
#    'EVC',
#    'FENG',
#    'HHS',
#    'LEE',
#    'SFUN',
#    'TSQ',
#    'BTN',
#    'LOV',
#    'NTN',
#    'TKAT',
#    'ZDGE'],
#   'Retail': ['ASNA',
#    'BGFV',
#    'BLNK',
#    'CJJD',
#    'CONN',
#    'CTRN',
#    'DLTH',
#    'DTEA',
#    'DXLG',
#    'FRAN',
#    'GRWG',
#    'IFMK',
#    'IMBI',
#    'KIRK',
#    'KXIN',
#    'LAZY',
#    'LMPX',
#    'LQDT',
#    'MARK',
#    'MKGI',
#    'MOHO',
#    'MOXC',
#    'MYT',
#    'PTS.TO',
#    'PRTS',
#    'RMBL',
#    'SECO',
#    'SMRT',
#    'TA',
#    'TLF',
#    'TUES',
#    'TWMC',
#    'WILC',
#    'WTRH',
#    'XELB',
#    'YTRA',
#    'APRN',
#    'ATV',
#    'BBW',
#    'BNED',
#    'CATO',
#    'CHS',
#    'EXPR',
#    'GNC',
#    'JILL',
#    'JMIA',
#    'LEAF',
#    'LEJU',
#    'LITB',
#    'MOGU',
#    'PRTY',
#    'RENN',
#    'RTW',
#    'TCS',
#    'TLRD',
#    'TLYS',
#    'BGI',
#    'ELA'],
#   'Leisure Products': ['EDNT', 'ESCA', 'JAKK', 'SUMR', 'NLS'],
#   'Textiles, Apparel & Luxury Goods': ['APEX',
#    'CRWS',
#    'CTHR',
#    'CTRC',
#    'DOGZ',
#    'EVK',
#    'FORD',
#    'FOSL',
#    'ICON',
#    'JRSH',
#    'KBSF',
#    'KGJI',
#    'LAKE',
#    'NAKD',
#    'RCKY',
#    'SGC',
#    'SQBG',
#    'VRA',
#    'CULP',
#    'MOV',
#    'UFI',
#    'VNCE',
#    'DLA'],
#   'Commercial Services & Supplies': ['AQMS',
#    'BHTG',
#    'CCRC',
#    'CECE',
#    'CREG',
#    'FTEK',
#    'HDSN',
#    'JAN',
#    'OMEX',
#    'PESI',
#    'PFMT',
#    'PICO',
#    'QRHC',
#    'VIRC',
#    'WHLM',
#    'ARC',
#    'ATTO',
#    'AXR',
#    'CHRA',
#    'CVEO',
#    'NL',
#    'QUAD',
#    'RRD',
#    'TISI',
#    'ACU',
#    'AWX',
#    'CIX',
#    'DSS'],
#   'Road & Rail': ['CVTI',
#    'DSKE',
#    'GLG',
#    'PATI',
#    'PTSI',
#    'USAK',
#    'YRCW',
#    'USX'],
#   'Utilities': ['CWCO',
#    'GWRS',
#    'PCYO',
#    'RGCO',
#    'SKYS',
#    'SPKE',
#    'VVPR',
#    'AT',
#    'ELJ',
#    'GNE',
#    'JE.TO',
#    'ELLO'],
#   'Trading Companies & Distributors': ['CLWT',
#    'GFN',
#    'HBP',
#    'HWCC',
#    'TITN',
#    'TRNS',
#    'WLFC',
#    'BXC',
#    'FLY',
#    'NSCO',
#    'ACY',
#    'IGC'],
#   'Beverages': ['BREW', 'EAST', 'NBEV', 'REED', 'WTER', 'WVVI'],
#   'Consumer products': ['BSET',
#    'CHCI',
#    'CTIB',
#    'CYAN',
#    'DXYN',
#    'FLXS',
#    'FORK',
#    'GHSI',
#    'HAPP',
#    'HEAR',
#    'HOFT',
#    'KOSS',
#    'LCUT',
#    'LFVN',
#    'LIVE',
#    'MTEX',
#    'MWK',
#    'MYOS',
#    'NAII',
#    'NATR',
#    'NEPH',
#    'NHTC',
#    'NVFY',
#    'OBCI',
#    'PFIN',
#    'RELV',
#    'SXTC',
#    'TYHT',
#    'UG',
#    'VERU',
#    'VOXX',
#    'VUZI',
#    'YGYI',
#    'ZAGG',
#    'HBB',
#    'HOV',
#    'NTZ',
#    'NWHM',
#    'ODC',
#    'LBY',
#    'MSN'],
#   'Auto Components': ['CAAS',
#    'CXDC',
#    'KNDI',
#    'SHLO',
#    'STRT',
#    'SYPR',
#    'VC',
#    'WKHS',
#    'HZN',
#    'SUP',
#    'UFAB'],
#   'Metals & Mining': ['CHNR',
#    'GSM',
#    'METC',
#    'OSN',
#    'SYNL',
#    'USAP',
#    'USAU',
#    'ZEUS',
#    'ZKIN',
#    'AP',
#    'MEC',
#    'MSB',
#    'OR',
#    'RYI',
#    'TMST',
#    'AMM.TO',
#    'ALO.TO',
#    'ASM.TO',
#    'AUG.TO',
#    'AUMN',
#    'CAL.TO',
#    'EMX.V',
#    'FRD',
#    'GMO',
#    'GORO',
#    'GPR.TO',
#    'GSV.TO',
#    'LODE',
#    'MTA.V',
#    'PTM.TO',
#    'PZG',
#    'SMT.TO',
#    'TKO.TO',
#    'TNX.TO',
#    'UAMY',
#    'VGZ',
#    'WRN.TO',
#    'XPL'],
#   'Distributors': ['EDUC', 'GNLN', 'WEYS', 'DIT'],
#   'Marine': ['EDRY',
#    'EGLE',
#    'ESEA',
#    'GLBS',
#    'GRIN',
#    'NMCI',
#    'PANL',
#    'PXS',
#    'SHIP',
#    'DAC',
#    'DSX',
#    'GSL',
#    'NM',
#    'NMM',
#    'SALT',
#    'SB'],
#   'Automobiles': ['FUV', 'SOLO'],
#   'Industrial Conglomerates': ['SPLP'],
#   'Paper & Forest': ['RFP', 'ITP'],
#   'Transportation Infrastructure': ['SINO'],
#   'Packaging': [],
#   'Tobacco': ['PYX', 'SDI', 'XXII']},
#  'MID_CAP': {'Diversified Consumer Services': ['ARCE',
#    'FTDR',
#    'LAUR',
#    'LOPE',
#    'STRA',
#    'BFAM',
#    'CHGG',
#    'GHC',
#    'GSX',
#    'HRB',
#    'SCI',
#    'SERV'],
#   'Airlines': ['AAL', 'ALGT', 'JBLU', 'SKYW', 'ALK', 'CPA', 'SAVE'],
#   'Insurance': ['ANAT',
#    'BHF',
#    'EHTH',
#    'ERIE',
#    'ESGR',
#    'GSHD',
#    'KNSL',
#    'NGHC',
#    'SIGI',
#    'AEL',
#    'AFG',
#    'AGO',
#    'AIZ',
#    'ATH',
#    'AXS',
#    'CNA',
#    'CNO',
#    'FAF',
#    'GL',
#    'KMPR',
#    'LNC',
#    'MCY',
#    'ORI',
#    'PRI',
#    'RE',
#    'RGA',
#    'RLI',
#    'RNR',
#    'THG',
#    'UNM',
#    'WTM',
#    'Y'],
#   'Communications': ['ACIA',
#    'COMM',
#    'FFIV',
#    'LITE',
#    'NTCT',
#    'SATS',
#    'VIAV',
#    'VSAT',
#    'CIEN',
#    'JNPR'],
#   'Building': ['AAON',
#    'BLDR',
#    'UFPI',
#    'AOS',
#    'AWI',
#    'FBHS',
#    'LII',
#    'OC',
#    'SSD',
#    'TREX',
#    'WMS'],
#   'Technology': ['ACIW',
#    'ALRM',
#    'APPF',
#    'APPN',
#    'AZPN',
#    'BL',
#    'BLKB',
#    'CDK',
#    'CSOD',
#    'CYBR',
#    'DBX',
#    'DOX',
#    'DSG.TO',
#    'EEFT',
#    'EPAY',
#    'EVBG',
#    'EVOP',
#    'EXLS',
#    'FEYE',
#    'FIVN',
#    'GDS',
#    'JCOM',
#    'LOGN.SW',
#    'LOGM',
#    'LPSN',
#    'MANH',
#    'MANT',
#    'MIME',
#    'NTNX',
#    'NUAN',
#    'PCTY',
#    'PEGA',
#    'PFPT',
#    'PS',
#    'PTC',
#    'QLYS',
#    'RP',
#    'RPD',
#    'SABR',
#    'SPSC',
#    'SVMK',
#    'TENB',
#    'TTEC',
#    'TWOU',
#    'VRNS',
#    'VRNT',
#    'ADS',
#    'AVLR',
#    'AYX',
#    'BB.TO',
#    'BILL',
#    'BOX',
#    'CACI',
#    'CLDR',
#    'CLGX',
#    'DAVA',
#    'DXC',
#    'ENV',
#    'ESTC',
#    'EVTC',
#    'FSLY',
#    'G',
#    'GLOB',
#    'GWRE',
#    'HUBS',
#    'KBR',
#    'MDLA',
#    'MMS',
#    'NCR',
#    'NET',
#    'NEWR',
#    'PD',
#    'PING',
#    'PLAN',
#    'PRSP',
#    'PSTG',
#    'QTWO',
#    'RAMP',
#    'SAIC',
#    'SAIL',
#    'SMAR',
#    'SWCH',
#    'SWI',
#    'TDC',
#    'WEX',
#    'WK',
#    'WNS',
#    'XRX',
#    'ZEN'],
#   'Logistics & Transportation': ['XPO'],
#   'Aerospace & Defense': ['AAXN',
#    'KTOS',
#    'MRCY',
#    'AJRD',
#    'BWXT',
#    'CAE.TO',
#    'CW',
#    'HII',
#    'HXL',
#    'MOG.A',
#    'PSN',
#    'SPCE',
#    'SPR',
#    'TXT'],
#   'Banking': ['AUB',
#    'BOKF',
#    'BPOP',
#    'CATY',
#    'CBSH',
#    'COLB',
#    'CSFL',
#    'CVBF',
#    'EWBC',
#    'FCNCA',
#    'FFIN',
#    'FHB',
#    'FIBK',
#    'GBCI',
#    'HOMB',
#    'HWC',
#    'IBKC',
#    'IBOC',
#    'INDB',
#    'ISBC',
#    'ONB',
#    'OZK',
#    'PACW',
#    'PBCT',
#    'PNFP',
#    'PPBI',
#    'SBNY',
#    'SFBS',
#    'SFNC',
#    'SSB',
#    'TCF',
#    'UBSI',
#    'UMBF',
#    'UMPQ',
#    'VLY',
#    'WTFC',
#    'ZION',
#    'ASB',
#    'BKU',
#    'BOH',
#    'BXS',
#    'CBU',
#    'CFR',
#    'CIT',
#    'CMA',
#    'FHN',
#    'FNB',
#    'PB',
#    'SNV',
#    'STL',
#    'WAL',
#    'WBS'],
#   'Biotechnology': ['ACAD',
#    'AGIO',
#    'ALEC',
#    'ALKS',
#    'ALLK',
#    'ALLO',
#    'AMRN',
#    'APLS',
#    'ARNA',
#    'ARWR',
#    'ASND',
#    'AUP.TO',
#    'BBIO',
#    'BLUE',
#    'BPMC',
#    'CBPO',
#    'CCXI',
#    'DCPH',
#    'DNLI',
#    'EIDX',
#    'EXEL',
#    'FATE',
#    'FGEN',
#    'FOLD',
#    'GBT',
#    'HALO',
#    'ICPT',
#    'IMMU',
#    'INSM',
#    'IONS',
#    'IOVA',
#    'KOD',
#    'KRTX',
#    'MNTA',
#    'MRTX',
#    'NTRA',
#    'NVAX',
#    'PTCT',
#    'QURE',
#    'RARE',
#    'TGTX',
#    'TPTX',
#    'UTHR',
#    'VIE',
#    'VIR',
#    'XLRN',
#    'ZLAB',
#    'BHVN',
#    'EBS',
#    'NVTA'],
#   'Health Care': ['ACHC',
#    'AMED',
#    'ATRC',
#    'CHNG',
#    'CVET',
#    'ENSG',
#    'GH',
#    'HMSY',
#    'HQY',
#    'HSIC',
#    'IART',
#    'ICUI',
#    'INOV',
#    'IRTC',
#    'LHCG',
#    'LIVN',
#    'LVGO',
#    'MMSI',
#    'NEOG',
#    'NUVA',
#    'NVCR',
#    'OMCL',
#    'PGNY',
#    'PINC',
#    'QDEL',
#    'SDC',
#    'TNDM',
#    'WMGI',
#    'AMN',
#    'CHE',
#    'CMD',
#    'EHC',
#    'GMED',
#    'HAE',
#    'HRC',
#    'INSP',
#    'ITGR',
#    'NVRO',
#    'NVST',
#    'PEN',
#    'SEM',
#    'THC',
#    'UHS'],
#   'Pharmaceuticals': ['ARVN',
#    'AXSM',
#    'CRON.TO',
#    'GWPH',
#    'HZNP',
#    'JAZZ',
#    'MYL',
#    'MYOK',
#    'NKTR',
#    'PCRX',
#    'RETA',
#    'ACB.TO',
#    'BHC.TO',
#    'WEED.TO',
#    'ELAN',
#    'PBH',
#    'PRGO',
#    'TARO'],
#   'Semiconductors': ['AEIS',
#    'AMKR',
#    'BRKS',
#    'CCMP',
#    'CREE',
#    'CRUS',
#    'DIOD',
#    'ENPH',
#    'ENTG',
#    'FORM',
#    'FSLR',
#    'LSCC',
#    'MKSI',
#    'MTSI',
#    'OLED',
#    'ON',
#    'POWI',
#    'SEDG',
#    'SLAB',
#    'SMTC',
#    'SYNA',
#    'TSEM.TA',
#    'IPHI'],
#   'Professional Services': ['EXPO',
#    'JOBS',
#    'ASGN',
#    'CCC',
#    'FCN',
#    'MAN',
#    'NLSN',
#    'NSP',
#    'RHI',
#    'STN.TO',
#    'TNET'],
#   'Chemicals': ['BCPC',
#    'IOSP',
#    'ALB',
#    'ASH',
#    'AXTA',
#    'CBT',
#    'CC',
#    'CF',
#    'ESI',
#    'FUL',
#    'GRA',
#    'HUN',
#    'KWR',
#    'MOS',
#    'NEU',
#    'NGVT',
#    'OLN',
#    'POL',
#    'SCL',
#    'SMG',
#    'SXT',
#    'VVV',
#    'WLK'],
#   'Life Sciences Tools & Services': ['ADPT',
#    'BRKR',
#    'ICLR',
#    'MEDP',
#    'NEO',
#    'PRAH',
#    'RGEN',
#    'SYNH',
#    'TECH',
#    'TXG',
#    'CRL'],
#   'Construction': ['ACA',
#    'ACM',
#    'BBU.UN.TO',
#    'EME',
#    'EXP',
#    'MTZ',
#    'PWR',
#    'VMI'],
#   'Hotels, Restaurants & Leisure': ['CBRL',
#    'CHDN',
#    'CZR',
#    'DNKN',
#    'ERI',
#    'MLCO',
#    'PENN',
#    'PZZA',
#    'STAY',
#    'TXRH',
#    'WEN',
#    'WING',
#    'ARMK',
#    'BYD',
#    'CHH',
#    'FUN',
#    'H',
#    'HGV',
#    'IGT',
#    'MTN',
#    'NCLH',
#    'PLNT',
#    'SHAK',
#    'SIX',
#    'VAC',
#    'WH',
#    'WYND'],
#   'Electrical Equipment': ['AVT',
#    'BLDP.TO',
#    'CGNX',
#    'COHR',
#    'FLEX',
#    'FLIR',
#    'IIVI',
#    'IPGP',
#    'ITRI',
#    'LFUS',
#    'NATI',
#    'NOVT',
#    'RUN',
#    'TECD',
#    'VICR',
#    'ARW',
#    'AXE',
#    'AYI',
#    'DLB',
#    'EAF',
#    'ENS',
#    'FN',
#    'GNRC',
#    'HUBB',
#    'JBL',
#    'NVT',
#    'RBC',
#    'ROG',
#    'SNX',
#    'ST',
#    'VSH'],
#   'Real Estate': ['AGNC',
#    'CIGI.TO',
#    'CONE',
#    'FSV.TO',
#    'GLPI',
#    'LAMR',
#    'PCH',
#    'RDFN',
#    'REG',
#    'SBRA',
#    'ACC',
#    'ADC',
#    'AIV',
#    'AMH',
#    'APLE',
#    'BDN',
#    'BRX',
#    'BXMT',
#    'CIM',
#    'COLD',
#    'COR',
#    'CPT',
#    'CUBE',
#    'CUZ',
#    'CWK',
#    'DEI',
#    'DOC',
#    'EGP',
#    'EPR',
#    'EQC',
#    'FR',
#    'FRT',
#    'GRT.UN.TO',
#    'HASI',
#    'HHC',
#    'HIW',
#    'HPP',
#    'HR',
#    'HTA',
#    'IRM',
#    'JBGS',
#    'JLL',
#    'KIM',
#    'KRC',
#    'KW',
#    'LSI',
#    'LXP',
#    'NHI',
#    'NNN',
#    'NRZ',
#    'NSA',
#    'OFC',
#    'OHI',
#    'OUT',
#    'PDM',
#    'PEB',
#    'PGRE',
#    'PK',
#    'PSB',
#    'QTS',
#    'REXR',
#    'RHP',
#    'RLJ',
#    'RYN',
#    'SAFE',
#    'SHO',
#    'SLG',
#    'SRC',
#    'STAG',
#    'STOR',
#    'STWD',
#    'TCO',
#    'TRNO',
#    'VER',
#    'VNO',
#    'WRE',
#    'WRI'],
#   'Financial Services': ['ARCC',
#    'CACC',
#    'FCFS',
#    'FOCS',
#    'FUTU',
#    'HLNE',
#    'LPLA',
#    'MORN',
#    'PSEC',
#    'SEIC',
#    'SLM',
#    'TFSL',
#    'TREE',
#    'VIRT',
#    'WAFD',
#    'AB',
#    'ALLY',
#    'AMG',
#    'AMK',
#    'APAM',
#    'CNNE',
#    'CNS',
#    'EQH',
#    'ESNT',
#    'EV',
#    'EVR',
#    'GDOT',
#    'HLI',
#    'IVZ',
#    'JEF',
#    'JHG',
#    'LAZ',
#    'LM',
#    'MAIN',
#    'MC',
#    'MTG',
#    'NNI',
#    'NYCB',
#    'OMF',
#    'ORCC',
#    'PFSI',
#    'PJT',
#    'RDN',
#    'SC',
#    'SF',
#    'VOYA'],
#   'Machinery': ['AIMC',
#    'FELE',
#    'KRNT',
#    'LECO',
#    'MIDD',
#    'ROLL',
#    'WWD',
#    'AGCO',
#    'AIN',
#    'ALSN',
#    'AQUA',
#    'B',
#    'CFX',
#    'CNHI.MI',
#    'CR',
#    'DCI',
#    'ESE',
#    'FLS',
#    'GGG',
#    'GTES',
#    'HI',
#    'ITT',
#    'JBT',
#    'KMT',
#    'NAV',
#    'OSK',
#    'PNR',
#    'PRLB',
#    'RXN',
#    'SNA',
#    'SPXC',
#    'TKR',
#    'TRN',
#    'TTC',
#    'WBC',
#    'WTS'],
#   'Food Products': ['BYND',
#    'CALM',
#    'FRPT',
#    'HAIN',
#    'JJSF',
#    'LANC',
#    'PPC',
#    'SAFM',
#    'BG',
#    'DAR',
#    'FLO',
#    'INGR',
#    'NOMD',
#    'POST',
#    'THS',
#    'TR',
#    'SEB'],
#   'Telecommunication': ['BAND',
#    'CCOI',
#    'GLIBA',
#    'IRDM',
#    'SHEN',
#    'VG',
#    'TDS',
#    'USM'],
#   'Energy ': ['APA',
#    'FANG',
#    'NBL',
#    'NFE',
#    'AM',
#    'APA',
#    'CCO.TO',
#    'CLR',
#    'CNX',
#    'COG',
#    'CVE.TO',
#    'CVI',
#    'CZZ',
#    'DCP',
#    'DVN',
#    'ENBL',
#    'EQM',
#    'EQT',
#    'ETRN',
#    'EURN.BR',
#    'FLNG.OL',
#    'HESM',
#    'HFC',
#    'MRO',
#    'MUR',
#    'PAA',
#    'PAGP',
#    'PE',
#    'SHLX',
#    'SUN',
#    'SWN',
#    'TCP',
#    'TPL',
#    'TRGP',
#    'WES',
#    'WPX',
#    'XEC'],
#   'Media': ['ANGI',
#    'CARG',
#    'CDLX',
#    'DOYU',
#    'LILA',
#    'MOMO',
#    'NWSA',
#    'NXST',
#    'SINA',
#    'TRIP',
#    'WB',
#    'YY',
#    'ZNGA',
#    'CNK',
#    'HUYA',
#    'IPG',
#    'JW.A',
#    'MANU',
#    'NYT',
#    'TGNA',
#    'WUBA',
#    'WWE'],
#   'Retail': ['BZUN',
#    'CASY',
#    'ETSY',
#    'EYE',
#    'FIVE',
#    'GO',
#    'OLLI',
#    'QRTEA',
#    'SFIX',
#    'SFM',
#    'STMP',
#    'AAN',
#    'AAP',
#    'AEO',
#    'AN',
#    'BJ',
#    'DKS',
#    'FL',
#    'FND',
#    'FTCH',
#    'FVRR',
#    'GPS',
#    'GRUB',
#    'JWN',
#    'KSS',
#    'LAD',
#    'LB',
#    'M',
#    'MUSA',
#    'PAG',
#    'PFGC',
#    'RH',
#    'USFD',
#    'WSM'],
#   'Leisure Products': ['DOO.TO', 'MAT', 'BC', 'GOLF', 'PII', 'YETI'],
#   'Textiles, Apparel & Luxury Goods': ['COLM',
#    'CROX',
#    'SHOO',
#    'CPRI',
#    'CRI',
#    'DECK',
#    'GIL.TO',
#    'GOOS.TO',
#    'HBI',
#    'LEVI',
#    'PVH',
#    'RL',
#    'SKX',
#    'TPR',
#    'UAA',
#    'WWW'],
#   'Commercial Services & Supplies': ['CMPR',
#    'CWST',
#    'SRCL',
#    'TTEK',
#    'ABM',
#    'ADSW',
#    'ADT',
#    'BCO',
#    'BRC',
#    'CLH',
#    'IAA',
#    'KAR',
#    'MSA',
#    'RBA.TO',
#    'UNF'],
#   'Road & Rail': ['CAR',
#    'LSTR',
#    'SAIA',
#    'UHAL',
#    'WERN',
#    'KNX',
#    'R',
#    'SNDR',
#    'TFII.TO'],
#   'Utilities': ['AY',
#    'MGEE',
#    'TERP',
#    'AES',
#    'ALE',
#    'AVA',
#    'AWR',
#    'BKH',
#    'CNP',
#    'CWT',
#    'EE',
#    'HE',
#    'IDA',
#    'MDU',
#    'NEP',
#    'NFG',
#    'NI',
#    'NJR',
#    'NRG',
#    'NWE',
#    'OGE',
#    'OGS',
#    'ORA',
#    'PCG',
#    'PNM',
#    'PNW',
#    'POR',
#    'SJI',
#    'SR',
#    'SWX',
#    'TA.TO',
#    'UGI'],
#   'Trading Companies & Distributors': ['BECN',
#    'HDS',
#    'AER',
#    'AIT',
#    'AL',
#    'GATX',
#    'MSM',
#    'SITE',
#    'TRTN',
#    'UNVR',
#    'WSO'],
#   'Beverages': ['COKE', 'FIZZ', 'SAM', 'TAP'],
#   'Consumer products': ['HELE',
#    'IRBT',
#    'LGIH',
#    'NWL',
#    'WDFC',
#    'BLD',
#    'COTY',
#    'ENR',
#    'HLF',
#    'IBP',
#    'KBH',
#    'LEG',
#    'MDC',
#    'MHK',
#    'MTH',
#    'NUS',
#    'PHM',
#    'SPB',
#    'TMHC',
#    'TOL',
#    'TPH',
#    'TPX',
#    'WHR'],
#   'Auto Components': ['DORM',
#    'FOXF',
#    'GNTX',
#    'GT',
#    'ADNT',
#    'ALV',
#    'BWA',
#    'DAN',
#    'LCII',
#    'LEA'],
#   'Metals & Mining': ['PAAS.TO',
#    'RGLD',
#    'SSRM',
#    'STLD',
#    'AA',
#    'FR.TO',
#    'AGI.TO',
#    'YRI.TO',
#    'CLF',
#    'CMC',
#    'IMG.TO',
#    'PVG.TO',
#    'RS',
#    'SSL.TO',
#    'TECK',
#    'TX',
#    'WOR',
#    'BTO.TO',
#    'EQX.TO',
#    'NG.TO'],
#   'Distributors': ['LKQ'],
#   'Marine': ['KEX'],
#   'Automobiles': ['HOG', 'NIO', 'THO', 'WGO'],
#   'Industrial Conglomerates': ['CSL'],
#   'Paper & Forest': ['LPX', 'OSB.TO'],
#   'Transportation Infrastructure': ['MIC'],
#   'Packaging': ['SLGN',
#    'ARD',
#    'ATR',
#    'BERY',
#    'CCK',
#    'GPK',
#    'SEE',
#    'SON',
#    'WRK'],
#   'Tobacco': []},
#  'MEGA_CAP': {'Diversified Consumer Services': [],
#   'Airlines': [],
#   'Insurance': [],
#   'Communications': ['CSCO'],
#   'Building': [],
#   'Technology': ['AAPL', 'MSFT', 'MA', 'V'],
#   'Logistics & Transportation': [],
#   'Aerospace & Defense': [],
#   'Banking': ['BAC', 'JPM'],
#   'Biotechnology': [],
#   'Health Care': ['UNH'],
#   'Pharmaceuticals': ['JNJ', 'MRK', 'PFE'],
#   'Semiconductors': ['INTC', 'NVDA'],
#   'Professional Services': [],
#   'Chemicals': [],
#   'Life Sciences Tools & Services': [],
#   'Construction': [],
#   'Hotels, Restaurants & Leisure': [],
#   'Electrical Equipment': [],
#   'Real Estate': [],
#   'Financial Services': ['BRK.A'],
#   'Machinery': [],
#   'Food Products': [],
#   'Telecommunication': ['T', 'VZ'],
#   'Energy ': ['XOM'],
#   'Media': ['FB', 'GOOGL', 'DIS'],
#   'Retail': ['AMZN', 'BABA', 'HD', 'WMT'],
#   'Leisure Products': [],
#   'Textiles, Apparel & Luxury Goods': [],
#   'Commercial Services & Supplies': [],
#   'Road & Rail': [],
#   'Utilities': [],
#   'Trading Companies & Distributors': [],
#   'Beverages': ['KO'],
#   'Consumer products': ['PG'],
#   'Auto Components': [],
#   'Metals & Mining': [],
#   'Distributors': [],
#   'Marine': [],
#   'Automobiles': [],
#   'Industrial Conglomerates': [],
#   'Paper & Forest': [],
#   'Transportation Infrastructure': [],
#   'Packaging': [],
#   'Tobacco': []},
#  'SMALL_CAP': {'Diversified Consumer Services': ['AFYA',
#    'APEI',
#    'FRG',
#    'HLG',
#    'HMHC',
#    'OSW',
#    'PRDO',
#    'WW',
#    'ATGE',
#    'BEDU',
#    'COE',
#    'CSV',
#    'LRN',
#    'NEW',
#    'ONE',
#    'RGS'],
#   'Airlines': ['HA', 'AZUL'],
#   'Insurance': ['AMSF',
#    'BRP',
#    'DGICA',
#    'FANH',
#    'GBLI',
#    'JRVR',
#    'NODK',
#    'NWLI',
#    'PLMR',
#    'SAFT',
#    'SG',
#    'STFC',
#    'TRUP',
#    'UFCS',
#    'UIHC',
#    'WTRE',
#    'ARGO',
#    'CIA',
#    'CRD.B',
#    'EIG',
#    'FFG',
#    'GNW',
#    'HCI',
#    'HMN',
#    'HRTG',
#    'IHC',
#    'MBI',
#    'PRA',
#    'PROS',
#    'STC',
#    'TPRE',
#    'UVE'],
#   'Communications': ['ADTN',
#    'AUDC',
#    'CASA',
#    'CMTL',
#    'DGII',
#    'EXTR',
#    'GILT.TA',
#    'HLIT',
#    'IDCC',
#    'INFN',
#    'INSG',
#    'ITRN',
#    'NTGR',
#    'RBBN',
#    'RDWR',
#    'SWIR',
#    'CALX',
#    'PLT'],
#   'Building': ['AMWD',
#    'APOG',
#    'CSTE',
#    'CSWI',
#    'IIIN',
#    'PATK',
#    'ROCK',
#    'CNR',
#    'DOOR',
#    'GFF',
#    'JELD',
#    'NX',
#    'PGTI',
#    'REZI'],
#   'Technology': ['AGYS',
#    'AMSWA',
#    'APPS',
#    'AVID',
#    'BCOV',
#    'BNFT',
#    'CAN',
#    'CASS',
#    'CATM',
#    'CNDT',
#    'CRNC',
#    'CSGS',
#    'CVLT',
#    'DOMO',
#    'EBIX',
#    'EGAN',
#    'EGOV',
#    'EIGI',
#    'FSCT',
#    'GSKY',
#    'HCKT',
#    'IIIV',
#    'IMXI',
#    'LLNW',
#    'MGIC',
#    'MITK',
#    'MJCO',
#    'MOBL',
#    'MSTR',
#    'MTLS',
#    'OPRA',
#    'OSPN',
#    'PAYS',
#    'PRFT',
#    'PRGS',
#    'QADA',
#    'QIWI',
#    'RMNI',
#    'RPAY',
#    'SCWX',
#    'SMCI',
#    'SPNS',
#    'SPT',
#    'SSYS',
#    'SYKE',
#    'TCX',
#    'TIVO',
#    'TLND',
#    'UPLD',
#    'VERI',
#    'VNET',
#    'VRRM',
#    'VRTU',
#    'ZIXI',
#    'ATEN',
#    'AVYA',
#    'CMCM',
#    'CTK',
#    'DBD',
#    'DDD',
#    'ECOM',
#    'EGHT',
#    'GTT',
#    'MODN',
#    'PRO',
#    'RST',
#    'TUFN',
#    'UIS',
#    'YEXT',
#    'ZUO',
#    'INS',
#    'VHC'],
#   'Logistics & Transportation': ['AAWW',
#    'ATSG',
#    'ECHO',
#    'FWRD',
#    'HUBG',
#    'BEST'],
#   'Aerospace & Defense': ['ATRO',
#    'AVAV',
#    'EH',
#    'AIR',
#    'ARNC',
#    'CUB',
#    'DCO',
#    'MAXR',
#    'NPK',
#    'TGI',
#    'VEC'],
#   'Banking': ['ABCB',
#    'ABTX',
#    'AMAL',
#    'AMNB',
#    'AMTB',
#    'AROW',
#    'BANF',
#    'BANR',
#    'BDGE',
#    'BFC',
#    'BFST',
#    'BMRC',
#    'BMTC',
#    'BPFH',
#    'BRKL',
#    'BSRR',
#    'BUSE',
#    'CAC',
#    'CATC',
#    'CBTX',
#    'CCBG',
#    'CCNE',
#    'CFB',
#    'CHCO',
#    'CNOB',
#    'CTBI',
#    'DCOM',
#    'EFSC',
#    'EGBN',
#    'FBMS',
#    'FBNC',
#    'FCBC',
#    'FFBC',
#    'FFIC',
#    'FFWM',
#    'FISI',
#    'FLIC',
#    'FMBH',
#    'FMBI',
#    'FMNB',
#    'FRME',
#    'FULT',
#    'GABC',
#    'GNTY',
#    'GSBC',
#    'HAFC',
#    'HBNC',
#    'HBT',
#    'HFWA',
#    'HONE',
#    'HOPE',
#    'HTBK',
#    'HTLF',
#    'IBCP',
#    'IBTX',
#    'LBAI',
#    'LKFN',
#    'LOB',
#    'MBWM',
#    'MCBS',
#    'MOFG',
#    'MSBI',
#    'NBTB',
#    'NCBS',
#    'OBNK',
#    'OPB',
#    'PEBO',
#    'PFBC',
#    'PGC',
#    'PUB',
#    'QCRH',
#    'RBCAA',
#    'RNST',
#    'SASR',
#    'SBCF',
#    'SBSI',
#    'SRCE',
#    'STBA',
#    'SYBT',
#    'TBBK',
#    'TBK',
#    'TCBI',
#    'TCBK',
#    'THFF',
#    'TOWN',
#    'TRMK',
#    'TSC',
#    'UCBI',
#    'UVSP',
#    'VBTX',
#    'WABC',
#    'WASH',
#    'WSBC',
#    'WTBA',
#    'BANC',
#    'BHLB',
#    'BY',
#    'CADE',
#    'CPF',
#    'CUBI',
#    'FBK',
#    'FBP',
#    'FCF',
#    'FSB',
#    'GWB',
#    'HTH',
#    'NBHC',
#    'NTB',
#    'OFG',
#    'BHB',
#    'PRK',
#    'TMP'],
#   'Biotechnology': ['ACIU',
#    'ADAP',
#    'ADVM',
#    'AGEN',
#    'AGLE',
#    'AIMT',
#    'AKBA',
#    'AKCA',
#    'AKRO',
#    'ALBO',
#    'ANAB',
#    'ANIK',
#    'APLT',
#    'APRE',
#    'APS.TO',
#    'ARCT',
#    'ARDX',
#    'ASMB',
#    'ATHX',
#    'ATNX',
#    'ATRA',
#    'AUTL',
#    'AVRO',
#    'BCEL',
#    'BCRX',
#    'BCYC',
#    'BLU.TO',
#    'BSTC',
#    'BTAI',
#    'BYSI',
#    'CALA',
#    'CDMO',
#    'CDNA',
#    'CHRS',
#    'CLVS',
#    'CNST',
#    'CPRX',
#    'CRBP',
#    'CRNX',
#    'CRTX',
#    'CSTL',
#    'CTMX',
#    'CUE',
#    'CYTK',
#    'DRNA',
#    'DTIL',
#    'DVAX',
#    'EDIT',
#    'EGRX',
#    'ENTA',
#    'EPZM',
#    'ESPR',
#    'ETNB',
#    'FIXX',
#    'FLXN',
#    'FREQ',
#    'GERN',
#    'GOSS',
#    'GTHX',
#    'HARP',
#    'HOOK',
#    'HRTX',
#    'IGMS',
#    'IMGN',
#    'IMVTU',
#    'INO',
#    'IRWD',
#    'KMDA.TA',
#    'KNSA',
#    'KPTI',
#    'KRYS',
#    'KURA',
#    'LGND',
#    'LMNL.TO',
#    'MCRB',
#    'MDGL',
#    'MEIP',
#    'MGNX',
#    'MGTA',
#    'MGTX',
#    'MIRM',
#    'MNKD',
#    'MORF',
#    'MRSN',
#    'MRUS',
#    'MTEM',
#    'MYGN',
#    'NK',
#    'NLTX',
#    'NTLA',
#    'NXTC',
#    'OPK',
#    'ORGO',
#    'ORTX',
#    'OYST',
#    'PBYI',
#    'PDLI',
#    'PGNX',
#    'PRNB',
#    'PRTA',
#    'PRVL',
#    'PTGX',
#    'PTLA',
#    'RAPT',
#    'RCKT',
#    'RDUS',
#    'REPL',
#    'RGNX',
#    'RIGL',
#    'RTRX',
#    'RUBY',
#    'RYTM',
#    'SAGE',
#    'SELB',
#    'SGMO',
#    'SNDX',
#    'SPPI',
#    'SRNE',
#    'SRRK',
#    'STML',
#    'STOK',
#    'STRO',
#    'SWTX',
#    'SYRS',
#    'TBIO',
#    'TCRR',
#    'TRIL.TO',
#    'TWST',
#    'UBX',
#    'URGN',
#    'VBIV',
#    'VCEL',
#    'VCYT',
#    'VKTX',
#    'VNDA',
#    'VSTM',
#    'VYGR',
#    'XBIT',
#    'XENE',
#    'XNCR',
#    'YMAB',
#    'ZIOP',
#    'KDMN',
#    'MYOV',
#    'RCUS',
#    'ZYME',
#    'CVM',
#    'PFNX'],
#   'Health Care': ['ADUS',
#    'AHCO',
#    'AMEH',
#    'ANGO',
#    'ATEC',
#    'ATRI',
#    'ATRS',
#    'AXGN',
#    'AXNX',
#    'BEAT',
#    'BLFS',
#    'BSGM',
#    'CATS',
#    'CERS',
#    'CODX',
#    'CPSI',
#    'CRVL',
#    'CSII',
#    'CTSO',
#    'CYRX',
#    'ESTA',
#    'FLGT',
#    'GNMK',
#    'HCAT',
#    'HSKA',
#    'HSTM',
#    'INGN',
#    'INMD',
#    'KIDS',
#    'KRMD',
#    'LMAT',
#    'LNTH',
#    'MDRX',
#    'MGLN',
#    'MLAB',
#    'NH',
#    'NRC',
#    'NTUS',
#    'NXGN',
#    'OFIX',
#    'OSUR',
#    'OXFD',
#    'PDCO',
#    'PETQ',
#    'PNTG',
#    'PRSC',
#    'QTNT',
#    'RCM',
#    'RDNT',
#    'SGRY',
#    'SIBN',
#    'SILK',
#    'SLP',
#    'SPNE',
#    'SRDX',
#    'STAA',
#    'SWAV',
#    'TCMD',
#    'TMDX',
#    'TRHC',
#    'TVTY',
#    'UTMD',
#    'VIVO',
#    'VMD.TO',
#    'VRAY',
#    'VREX',
#    'VRML',
#    'ZYXI',
#    'AVNS',
#    'BKD',
#    'CO',
#    'CRY',
#    'CYH',
#    'EVH',
#    'GKOS',
#    'GTS',
#    'HNGR',
#    'MD',
#    'OMI',
#    'PHR',
#    'USPH',
#    'VAPO',
#    'VCRA',
#    'NHC',
#    'STXS'],
#   'Pharmaceuticals': ['AERI',
#    'AMPH',
#    'ANIP',
#    'APHA.TO',
#    'AVDL',
#    'BDSI',
#    'CARA',
#    'COLL',
#    'CORT',
#    'DRRX',
#    'ENDP',
#    'FULC',
#    'INVA',
#    'ITCI',
#    'KALA',
#    'MNLO',
#    'NGM',
#    'OCUL',
#    'ODT',
#    'OGI.TO',
#    'OMER',
#    'OSMT',
#    'PAHC',
#    'PHAT',
#    'PRVB',
#    'RLMD',
#    'RVNC',
#    'SIGA',
#    'STSA',
#    'SUPN',
#    'TBPH',
#    'TCDA',
#    'TLRY',
#    'TXMD',
#    'UROV',
#    'VRCA',
#    'WVE',
#    'XENT',
#    'ZGNX',
#    'AMRX',
#    'APHA.TO',
#    'HEXO.TO',
#    'LCI'],
#   'Semiconductors': ['ACLS',
#    'ACMR',
#    'AMBA',
#    'AOSL',
#    'CAMT',
#    'CEVA',
#    'COHU',
#    'CSIQ',
#    'DSPG',
#    'HIMX',
#    'ICHR',
#    'IOTS',
#    'KLIC',
#    'NVEC',
#    'NVMI',
#    'PDFS',
#    'PI',
#    'PLAB',
#    'RMBS',
#    'SGH',
#    'SIMO',
#    'SITM',
#    'SPWR',
#    'UCTT',
#    'VECO',
#    'XPER',
#    'DQ',
#    'JKS',
#    'MX',
#    'MXL',
#    'NPTN',
#    'ONTO'],
#   'Professional Services': ['BBSI',
#    'CRAI',
#    'FORR',
#    'HSII',
#    'HURN',
#    'ICFI',
#    'KELYA',
#    'KFRC',
#    'UPWK',
#    'WLDN',
#    'CBZ',
#    'FC',
#    'KFY',
#    'TBI'],
#   'Chemicals': ['AMRS',
#    'HWKN',
#    'LOOP',
#    'ASIX',
#    'AVD',
#    'FF',
#    'FOE',
#    'GCP',
#    'KOP',
#    'KRA',
#    'KRO',
#    'LTHM',
#    'MTX',
#    'OEC',
#    'PQG',
#    'TG',
#    'TROX',
#    'TSE',
#    'VHI',
#    'WLKP',
#    'CCF'],
#   'Life Sciences Tools & Services': ['AXDX',
#    'CDXS',
#    'CGEN',
#    'LMNX',
#    'NSTG',
#    'PACB',
#    'PSNL',
#    'QTRX'],
#   'Construction': ['AEGN',
#    'FRTA',
#    'GLDD',
#    'IESC',
#    'MYRG',
#    'NVEE',
#    'PRIM',
#    'ROAD',
#    'STRL',
#    'USCR',
#    'USLM',
#    'WSC',
#    'AGX',
#    'AMRC',
#    'DY',
#    'FIX',
#    'FLR',
#    'GVA',
#    'SUM',
#    'TPC'],
#   'Hotels, Restaurants & Leisure': ['BJRI',
#    'BLMN',
#    'CAKE',
#    'CHUY',
#    'DENN',
#    'GDEN',
#    'JACK',
#    'LIND',
#    'LK',
#    'LOCO',
#    'MCRI',
#    'PLAY',
#    'PLYA',
#    'RRR',
#    'RUTH',
#    'SGMS',
#    'TH',
#    'ACEL',
#    'ARCO',
#    'BXG',
#    'DIN',
#    'EAT',
#    'EVRI',
#    'GHG',
#    'MSC',
#    'SEAS',
#    'TRWH'],
#   'Electrical Equipment': ['AKTS',
#    'AMOT',
#    'CNXN',
#    'FARO',
#    'FCEL',
#    'HOLI',
#    'KE',
#    'LASR',
#    'MTSC',
#    'NSIT',
#    'NSSC',
#    'OSIS',
#    'PLUG',
#    'PLUS',
#    'PLXS',
#    'POWL',
#    'SANM',
#    'SCSC',
#    'TPIC',
#    'TTMI',
#    'WIRE',
#    'ATKR',
#    'AZZ',
#    'BDC',
#    'BE',
#    'BHE',
#    'BMI',
#    'CLS.TO',
#    'CTS',
#    'FIT',
#    'HMI',
#    'KEM',
#    'KN',
#    'MEI',
#    'PAR',
#    'THR',
#    'VPG',
#    'VSLR'],
#   'Real Estate': ['AFIN',
#    'CTRE',
#    'DHC',
#    'EXPI',
#    'FRPH',
#    'GOOD',
#    'ILPT',
#    'LAND',
#    'NMRK',
#    'NYMT',
#    'OPI',
#    'QK',
#    'RMR',
#    'ROIC',
#    'SVC',
#    'UNIT',
#    'AAT',
#    'ABR',
#    'ACRE',
#    'AHH',
#    'AKR',
#    'ALEX',
#    'ALX',
#    'APTS',
#    'ARI',
#    'ARR',
#    'BFS',
#    'CHCT',
#    'CIO',
#    'CLDT',
#    'CLI',
#    'CLNC',
#    'CLNY',
#    'CMO',
#    'CTT',
#    'CXP',
#    'CXW',
#    'DEA',
#    'DRH',
#    'DX',
#    'EFC',
#    'EPRT',
#    'ESRT',
#    'FCPT',
#    'FOR',
#    'FPH',
#    'GEO',
#    'GMRE',
#    'GNL',
#    'GPMT',
#    'GTY',
#    'HT',
#    'IIPR',
#    'INN',
#    'IRET',
#    'IRT',
#    'IVR',
#    'JCAP',
#    'JOE',
#    'KREF',
#    'KRG',
#    'LADR',
#    'LTC',
#    'MAC',
#    'MFA',
#    'MMI',
#    'MNR',
#    'NXRT',
#    'OLP',
#    'ORC',
#    'PMT',
#    'RC',
#    'RESI',
#    'RLGY',
#    'RMAX',
#    'RPAI',
#    'RPT',
#    'RVI',
#    'RWT',
#    'SITC',
#    'SKT',
#    'SNR',
#    'SRG',
#    'STAR',
#    'TRC',
#    'TRTX',
#    'TWO',
#    'UBA',
#    'UE',
#    'UHT',
#    'UMH',
#    'WSR',
#    'XHR',
#    'FSP'],
#   'Financial Services': ['AGMH',
#    'AINV',
#    'ALRS',
#    'BCOR',
#    'BGCP',
#    'BWB',
#    'CASH',
#    'CFFN',
#    'CGBD',
#    'CLBK',
#    'COOP',
#    'COWN',
#    'DHIL',
#    'EBSB',
#    'ECPG',
#    'EZPW',
#    'FDEF',
#    'FRHC',
#    'GAIN',
#    'GBDC',
#    'HIFS',
#    'HMST',
#    'INTL',
#    'KRNY',
#    'LBC',
#    'LX',
#    'MBIN',
#    'NAVI',
#    'NEWT',
#    'NFBK',
#    'NMIH',
#    'NWBI',
#    'OCFC',
#    'OCSL',
#    'OPRT',
#    'PFLT',
#    'PRAA',
#    'QFIN',
#    'RILY',
#    'SLRC',
#    'TCPC',
#    'TIGR',
#    'TRST',
#    'VCTR',
#    'VRTS',
#    'WETF',
#    'WRLD',
#    'WSBF',
#    'WSFS',
#    'YIN',
#    'AC',
#    'AGM',
#    'AX',
#    'BBDC',
#    'BCSF',
#    'BLX',
#    'BSIG',
#    'CODI',
#    'CURO',
#    'DFIN',
#    'ENVA',
#    'FBC',
#    'FG',
#    'FINV',
#    'FSK',
#    'GBL',
#    'GSBD',
#    'HKIB',
#    'HTGC',
#    'LC',
#    'NMFC',
#    'NOAH',
#    'OPY',
#    'PFS',
#    'PIPR',
#    'PZN',
#    'QD',
#    'SCU',
#    'TPVG',
#    'TSLX',
#    'WD',
#    'WDR',
#    'YRD'],
#   'Machinery': ['ASTE',
#    'BLBD',
#    'CMCO',
#    'ERII',
#    'GTLS',
#    'HLIO',
#    'OFLX',
#    'SPAR',
#    'TRS',
#    'ALG',
#    'CIR',
#    'CYD',
#    'EPAC',
#    'FLOW',
#    'FSS',
#    'GBX',
#    'GRC',
#    'HY',
#    'KAI',
#    'LDL',
#    'LNN',
#    'LXFR',
#    'MLI',
#    'MLR',
#    'MTOR',
#    'MTW',
#    'MWA',
#    'NPO',
#    'PLOW',
#    'REVG',
#    'SXI',
#    'TEX',
#    'TNC',
#    'WBT',
#    'WNC'],
#   'Food Products': ['CVGW',
#    'JBSS',
#    'LNDC',
#    'SENEA',
#    'SMPL',
#    'SOY.TO',
#    'TWNK',
#    'VFF.TO',
#    'AGRO',
#    'BGS',
#    'FDP'],
#   'Telecommunication': ['ATEX',
#    'ATNI',
#    'BCOM.TA',
#    'CNSL',
#    'ORBC',
#    'WIFI',
#    'CBB',
#    'OOMA',
#    'GSAT'],
#   'Energy ': ['ALTM',
#    'ARLP',
#    'BROG',
#    'BRY',
#    'CDEV',
#    'CLNE',
#    'DMLP',
#    'FLMN',
#    'GLNG',
#    'GPOR',
#    'GPRE',
#    'NBLX',
#    'OAS',
#    'OMP',
#    'PDCE',
#    'REGI',
#    'RTLR',
#    'TELL',
#    'VNOM',
#    'AR',
#    'ARCH',
#    'BCEI',
#    'BPMP',
#    'BSM',
#    'BTE.TO',
#    'BTU',
#    'CAPL',
#    'CEQP',
#    'CNXM',
#    'CPE',
#    'CPG.TO',
#    'CRK',
#    'DHT',
#    'DK',
#    'DKL',
#    'DSSI',
#    'ENLC',
#    'ERF.TO',
#    'EVA',
#    'GEL',
#    'GLOG',
#    'GLP',
#    'GPRK',
#    'HEP',
#    'HMLP',
#    'INSW',
#    'INT',
#    'KNOP',
#    'KOS',
#    'KRP',
#    'LPG',
#    'LPI',
#    'MGY',
#    'MNRL',
#    'MTDR',
#    'NAT',
#    'NGL',
#    'NS',
#    'NVGS',
#    'PARR',
#    'PBF',
#    'PBFX',
#    'QEP',
#    'REX',
#    'RRC',
#    'SBR',
#    'SFL',
#    'SM',
#    'SRLP',
#    'STNG',
#    'TALO',
#    'TGP',
#    'TK',
#    'TNK',
#    'VET.TO',
#    'WTI',
#    'DML.TO',
#    'MCF',
#    'NOG',
#    'NXE.TO'],
#   'Media': ['AMCX',
#    'BOMN',
#    'CETV',
#    'CRTO',
#    'DJCO',
#    'DUO',
#    'EVER',
#    'GLUU',
#    'GRVY',
#    'HMTV',
#    'ICLK',
#    'IHRT',
#    'JFU',
#    'LORL',
#    'LTRPA',
#    'MEET',
#    'QNST',
#    'QTT',
#    'SBGI',
#    'SCHL',
#    'SCPL',
#    'SOHU',
#    'SSP',
#    'SY',
#    'TPCO',
#    'TRUE',
#    'TRVG',
#    'TTGT',
#    'WSG',
#    'AMC',
#    'BITA',
#    'CARS',
#    'CCO',
#    'EB',
#    'EROS',
#    'ETM',
#    'GCI',
#    'GTN',
#    'IMAX',
#    'LGF.A',
#    'MCS',
#    'MDP',
#    'MSGN',
#    'SOGO',
#    'WOW',
#    'YELP'],
#   'Retail': ['ANDE',
#    'BBBY',
#    'CHEF',
#    'CRMT',
#    'FLWS',
#    'GRPN',
#    'HFFG',
#    'HIBB',
#    'IMKTA',
#    'LE',
#    'MIK',
#    'MMYT',
#    'MNRO',
#    'ODP',
#    'OSTK',
#    'PETS',
#    'PLCE',
#    'PSMT',
#    'RCII',
#    'REAL',
#    'RUBI',
#    'RUHN',
#    'SCVL',
#    'SNBR',
#    'SPTN',
#    'SPWH',
#    'URBN',
#    'UXIN',
#    'VLGEA',
#    'WINA',
#    'YI',
#    'YJ',
#    'ZUMZ',
#    'ABG',
#    'ANF',
#    'BIG',
#    'BKE',
#    'BOOT',
#    'CAL',
#    'CANG',
#    'CWH',
#    'DBI',
#    'DDS',
#    'DESP',
#    'GCO',
#    'GES',
#    'GME',
#    'GPI',
#    'HOME',
#    'HUD',
#    'HVT',
#    'HZO',
#    'LL',
#    'NGVC',
#    'QUOT',
#    'RAD',
#    'RUBI',
#    'RVLV',
#    'SAH',
#    'SBH',
#    'SIG',
#    'SSTK',
#    'UNFI',
#    'WMK'],
#   'Leisure Products': ['AOBC',
#    'CLAR',
#    'GNUS',
#    'JOUT',
#    'MBUU',
#    'MCFT',
#    'ELY',
#    'MPX',
#    'RGR',
#    'VSTO'],
#   'Textiles, Apparel & Luxury Goods': ['GIII', 'KTB', 'OXM'],
#   'Commercial Services & Supplies': ['ECOL',
#    'HCCI',
#    'HCSG',
#    'KBAL',
#    'MATW',
#    'MGRC',
#    'MINI',
#    'MLHR',
#    'SP',
#    'TILE',
#    'VSEC',
#    'ACCO',
#    'BV',
#    'CVA',
#    'DLX',
#    'EBF',
#    'HNI',
#    'HSC',
#    'KNL',
#    'PBI',
#    'SCS',
#    'VVI',
#    'AXU.TO'],
#   'Road & Rail': ['ARCB', 'HTLD', 'MRTN', 'ULH', 'HTZ'],
#   'Utilities': ['ARTNA',
#    'CDZI',
#    'MSEX',
#    'OTTR',
#    'YORW',
#    'AZRE',
#    'CPK',
#    'KEN',
#    'NOVA',
#    'NWN',
#    'SGU',
#    'SJW',
#    'SPH',
#    'UTL'],
#   'Trading Companies & Distributors': ['BMCH',
#    'DXPE',
#    'HEES',
#    'LAWS',
#    'RUSHA',
#    'CAI',
#    'DNOW',
#    'FBM',
#    'FTAI',
#    'GMS',
#    'HRI',
#    'KAMN',
#    'MRC',
#    'SYX',
#    'TGH',
#    'VRTV',
#    'WCC',
#    'EVI'],
#   'Beverages': ['CELH', 'MGPI', 'PRMW'],
#   'Consumer products': ['CENT',
#    'CVCO',
#    'GPRO',
#    'GRBK',
#    'IPAR',
#    'LEGH',
#    'LOVE',
#    'NEPT.TO',
#    'PRPL',
#    'SONO',
#    'UEIC',
#    'VIOT',
#    'BRBR',
#    'BZH',
#    'CCS',
#    'ELF',
#    'EPC',
#    'ETH',
#    'LZB',
#    'MED',
#    'MHO',
#    'REV',
#    'SKY',
#    'TUP',
#    'USNA'],
#   'Auto Components': ['MPAA',
#    'THRM',
#    'XPEL',
#    'AXL',
#    'CPS',
#    'CTB',
#    'DLPH',
#    'GTX',
#    'MOD',
#    'SMP',
#    'SRI',
#    'TEN',
#    'VNE'],
#   'Metals & Mining': ['CENX',
#    'HAYN',
#    'KALU',
#    'SCHN',
#    'ATI',
#    'CDE',
#    'CMP',
#    'CRS',
#    'ELD.TO',
#    'EDR.TO',
#    'FVI.TO',
#    'HBM.TO',
#    'HCC',
#    'HL',
#    'LAC.TO',
#    'MTRN',
#    'MUX',
#    'NEXA',
#    'SEA.TO',
#    'SXC',
#    'TRQ.TO',
#    'X',
#    'GAU.TO',
#    'GSC.TO',
#    'MAG.TO',
#    'MMX.TO',
#    'NDM.TO',
#    'NGD.TO',
#    'POM.TO',
#    'SIL.TO',
#    'SVM.TO',
#    'ITH.TO',
#    'TMQ.TO',
#    'USA.TO'],
#   'Distributors': ['CORE', 'FNKO'],
#   'Marine': ['CTRM', 'GOGL', 'SBLK', 'CMRE', 'GNK', 'MATX'],
#   'Automobiles': ['NIU'],
#   'Industrial Conglomerates': ['RAVN'],
#   'Paper & Forest': ['MERC', 'BCC', 'CLW', 'GLT', 'NP', 'SWM', 'UFS', 'VRS'],
#   'Transportation Infrastructure': ['CAAP'],
#   'Packaging': ['UFPT', 'GEF', 'MYE', 'PACK'],
#   'Tobacco': ['TPB', 'UVV', 'VGR']},
#  'LARGE_CAP': {'Diversified Consumer Services': ['EDU', 'TAL'],
#   'Airlines': ['UAL', 'DAL', 'LUV'],
#   'Insurance': ['ACGL',
#    'CINF',
#    'PFG',
#    'WLTW',
#    'AFL',
#    'AIG',
#    'AJG',
#    'ALL',
#    'AON',
#    'BRO',
#    'CB',
#    'FNF',
#    'HIG',
#    'L',
#    'MET',
#    'MFC.TO',
#    'MKL',
#    'MMC',
#    'PGR',
#    'PRU',
#    'SLF.TO',
#    'TRV',
#    'WRB'],
#   'Communications': ['ANET', 'MSI', 'UI'],
#   'Building': ['ALLE', 'JCI', 'MAS'],
#   'Technology': ['ADBE',
#    'ADP',
#    'ADSK',
#    'AKAM',
#    'ANSS',
#    'CDNS',
#    'CHKP',
#    'COUP',
#    'CRWD',
#    'CTSH',
#    'CTXS',
#    'DDOG',
#    'DOCU',
#    'FISV',
#    'FTNT',
#    'INTU',
#    'JKHY',
#    'MDB',
#    'NLOK',
#    'NTAP',
#    'OKTA',
#    'OTEX.TO',
#    'PAYX',
#    'PYPL',
#    'SNPS',
#    'SPLK',
#    'SSNC',
#    'STNE',
#    'STX',
#    'TEAM',
#    'TTD',
#    'VRSN',
#    'WDAY',
#    'WDC',
#    'WIX',
#    'ZM',
#    'ZS',
#    'ACN',
#    'BAH',
#    'BKI',
#    'BR',
#    'CDAY',
#    'CRM',
#    'DELL',
#    'DT',
#    'EPAM',
#    'FICO',
#    'FIS',
#    'FLT',
#    'GDDY',
#    'GIB.A.TO',
#    'GPN',
#    'HPE',
#    'HPQ',
#    'IBM',
#    'IT',
#    'LDOS',
#    'NOW',
#    'ORCL',
#    'PAGS',
#    'PANW',
#    'PAYC',
#    'RNG',
#    'SHOP',
#    'SQ',
#    'TWLO',
#    'TYL',
#    'VMW',
#    'WORK',
#    'WU'],
#   'Logistics & Transportation': ['CHRW', 'EXPD', 'FDX', 'UPS', 'ZTO'],
#   'Aerospace & Defense': ['ESLT.TA',
#    'BA',
#    'GD',
#    'HEI',
#    'LHX',
#    'LMT',
#    'NOC',
#    'TDG',
#    'TDY'],
#   'Banking': ['FITB',
#    'HBAN',
#    'SIVB',
#    'BAP',
#    'BMO.TO',
#    'BNS.TO',
#    'C',
#    'CFG',
#    'CM.TO',
#    'FRC',
#    'KEY',
#    'MTB',
#    'PNC',
#    'RF',
#    'RY.TO',
#    'TD.TO',
#    'USB',
#    'WFC'],
#   'Biotechnology': ['ALNY',
#    'ALXN',
#    'AMGN',
#    'BIIB',
#    'BMRN',
#    'BNTX',
#    'EXAS',
#    'GILD',
#    'INCY',
#    'MRNA',
#    'NBIX',
#    'REGN',
#    'SGEN',
#    'SRPT',
#    'VRTX',
#    'ABBV'],
#   'Health Care': ['ABMD',
#    'ALGN',
#    'CERN',
#    'DXCM',
#    'HOLX',
#    'IDXX',
#    'ISRG',
#    'MASI',
#    'PODD',
#    'XRAY',
#    'ABC',
#    'ABT',
#    'ALC.SW',
#    'ANTM',
#    'BAX',
#    'BDX',
#    'BSX',
#    'CAH',
#    'CI',
#    'CNC',
#    'COO',
#    'CVS',
#    'DGX',
#    'DHR',
#    'DVA',
#    'EW',
#    'HCA',
#    'HUM',
#    'LH',
#    'MCK',
#    'MDT',
#    'MOH',
#    'RMD',
#    'STE',
#    'SYK',
#    'TDOC',
#    'TFX',
#    'VAR',
#    'VEEV',
#    'WST',
#    'ZBH'],
#   'Pharmaceuticals': ['BMY', 'BMY', 'CTLT', 'LLY', 'ZTS'],
#   'Semiconductors': ['ADI',
#    'AMAT',
#    'AMD',
#    'AVGO',
#    'KLAC',
#    'LRCX',
#    'MCHP',
#    'MPWR',
#    'MRVL',
#    'MU',
#    'MXIM',
#    'NXPI',
#    'QCOM',
#    'QRVO',
#    'SWKS',
#    'TER',
#    'TXN',
#    'XLNX'],
#   'Professional Services': ['CSGP', 'VRSK', 'EFX', 'INFO', 'TRI.TO', 'TRU'],
#   'Chemicals': ['APD',
#    'CE',
#    'CTVA',
#    'DD',
#    'DOW',
#    'ECL',
#    'EMN',
#    'FMC',
#    'ICL.TA',
#    'IFF',
#    'LIN',
#    'LYB',
#    'NTR.TO',
#    'PPG',
#    'RPM',
#    'SHW'],
#   'Life Sciences Tools & Services': ['ILMN',
#    'A',
#    'AVTR',
#    'BIO',
#    'IQV',
#    'MTD',
#    'PKI',
#    'QGEN',
#    'TMO',
#    'WAT'],
#   'Construction': ['J', 'MLM', 'VMC'],
#   'Hotels, Restaurants & Leisure': ['HTHT',
#    'MAR',
#    'SBUX',
#    'WYNN',
#    'CCL',
#    'CMG',
#    'DPZ',
#    'DRI',
#    'HLT',
#    'LVS',
#    'MCD',
#    'MGM',
#    'QSR.TO',
#    'RCL',
#    'YUM',
#    'YUMC'],
#   'Electrical Equipment': ['CDW',
#    'TRMB',
#    'ZBRA',
#    'AME',
#    'APH',
#    'EMR',
#    'ETN',
#    'GLW',
#    'KEYS',
#    'ROK',
#    'TEL'],
#   'Real Estate': ['BPY',
#    'EQIX',
#    'SBAC',
#    'AMT',
#    'ARE',
#    'AVB',
#    'BXP',
#    'CBRE',
#    'CCI',
#    'DLR',
#    'DRE',
#    'ELS',
#    'EQR',
#    'ESS',
#    'EXR',
#    'HST',
#    'INVH',
#    'MAA',
#    'MGP',
#    'MPW',
#    'NLY',
#    'O',
#    'PEAK',
#    'PLD',
#    'PSA',
#    'SPG',
#    'SUI',
#    'UDR',
#    'VICI',
#    'VTR',
#    'WELL',
#    'WPC',
#    'WY'],
#   'Financial Services': ['AMTD',
#    'CG',
#    'CME',
#    'ETFC',
#    'IBKR',
#    'MKTX',
#    'NDAQ',
#    'NTRS',
#    'TROW',
#    'TW',
#    'XP',
#    'AMP',
#    'APO',
#    'ARES',
#    'AXP',
#    'BAM.A.TO',
#    'BEN',
#    'BK',
#    'BLK',
#    'BX',
#    'COF',
#    'DBK.DE',
#    'DFS',
#    'FDS',
#    'GS',
#    'ICE',
#    'KKR',
#    'MCO',
#    'MS',
#    'MSCI',
#    'RJF',
#    'SCHW',
#    'SPGI',
#    'STT',
#    'SYF',
#    'UBSG.SW',
#    'CBOE'],
#   'Machinery': ['NDSN',
#    'PCAR',
#    'CAT',
#    'CMI',
#    'DE',
#    'DOV',
#    'FTV',
#    'IEX',
#    'IR',
#    'ITW',
#    'PH',
#    'SWK',
#    'WAB',
#    'XYL'],
#   'Food Products': ['KHC',
#    'MDLZ',
#    'ADM',
#    'CAG',
#    'CPB',
#    'GIS',
#    'HRL',
#    'HSY',
#    'K',
#    'LW',
#    'MKC',
#    'SJM',
#    'TSN'],
#   'Telecommunication': ['TMUS', 'BCE.TO', 'CTL', 'RCI.B.TO', 'T.TO'],
#   'Energy ': ['CNQ.TO',
#    'COP',
#    'CVX',
#    'CXO',
#    'ENB.TO',
#    'EOG',
#    'EPD',
#    'ET',
#    'FRO.OL',
#    'HES',
#    'KMI',
#    'MMP',
#    'MPC',
#    'MPLX',
#    'OKE',
#    'OXY',
#    'PPL.TO',
#    'PSX',
#    'PSXP',
#    'PXD',
#    'SU.TO',
#    'TRP.TO',
#    'VLO',
#    'WMB',
#    'CQP',
#    'IMO.TO',
#    'LNG'],
#   'Media': ['ATVI',
#    'BIDU',
#    'BILI',
#    'CHTR',
#    'CMCSA',
#    'DISCA',
#    'DISH',
#    'EA',
#    'FOXA',
#    'FWONA',
#    'IAC',
#    'LBRDA',
#    'LBTYA',
#    'MTCH',
#    'NFLX',
#    'NTES',
#    'ROKU',
#    'SIRI',
#    'TTWO',
#    'VIAC',
#    'YNDX',
#    'ZG',
#    'ATHM',
#    'ATUS',
#    'CABO',
#    'LYV',
#    'OMC',
#    'PINS',
#    'SE',
#    'SJR.B.TO',
#    'SNAP',
#    'SPOT',
#    'TME',
#    'TWTR'],
#   'Retail': ['BKNG',
#    'COST',
#    'DLTR',
#    'EBAY',
#    'EXPE',
#    'JD',
#    'MELI',
#    'ORLY',
#    'PDD',
#    'ROST',
#    'TCOM',
#    'TSCO',
#    'ULTA',
#    'WBA',
#    'AZO',
#    'BBY',
#    'BURL',
#    'CHWY',
#    'CVNA',
#    'DG',
#    'KMX',
#    'KR',
#    'LOW',
#    'SYY',
#    'TGT',
#    'TIF',
#    'TJX',
#    'VIPS',
#    'W'],
#   'Leisure Products': ['HAS', 'PTON'],
#   'Textiles, Apparel & Luxury Goods': ['LULU', 'NKE', 'VFC'],
#   'Commercial Services & Supplies': ['CPRT',
#    'CTAS',
#    'ROL',
#    'RSG',
#    'WCN.TO',
#    'WM'],
#   'Road & Rail': ['CSX',
#    'JBHT',
#    'LYFT',
#    'ODFL',
#    'CNR.TO',
#    'CP.TO',
#    'KSU',
#    'KSU',
#    'NSC',
#    'UBER',
#    'UNP'],
#   'Utilities': ['EXC',
#    'LNT',
#    'XEL',
#    'AEE',
#    'AEP',
#    'AGR',
#    'AQN.TO',
#    'ATO',
#    'AWK',
#    'BEP.UN.TO',
#    'BIP',
#    'CMS',
#    'D',
#    'DTE',
#    'DUK',
#    'ED',
#    'EIX',
#    'ES',
#    'ETR',
#    'EVRG',
#    'FE',
#    'FTS.TO',
#    'NEE',
#    'PEG',
#    'PPL',
#    'SO',
#    'SRE',
#    'VST',
#    'WEC'],
#   'Trading Companies & Distributors': ['FAST', 'GWW', 'URI'],
#   'Beverages': ['MNST', 'PEP', 'BF.B', 'CCEP', 'KDP', 'STZ'],
#   'Consumer products': ['GRMN',
#    'CHD',
#    'CL',
#    'CLX',
#    'DHI',
#    'EL',
#    'KMB',
#    'LEN',
#    'NVR'],
#   'Auto Components': ['APTV', 'MG.TO'],
#   'Metals & Mining': ['AEM.TO',
#    'FCX',
#    'FNV.TO',
#    'ABX.TO',
#    'K.TO',
#    'KL.TO',
#    'NEM',
#    'NUE',
#    'SCCO',
#    'WPM.TO'],
#   'Distributors': ['POOL', 'GPC'],
#   'Marine': [],
#   'Automobiles': ['TSLA', 'F', 'FCA.MI', 'GM', 'RACE.MI'],
#   'Industrial Conglomerates': ['IEP', 'GE', 'HON', 'MMM', 'ROP'],
#   'Paper & Forest': [],
#   'Transportation Infrastructure': [],
#   'Packaging': ['AMCR', 'AVY', 'BLL', 'IP', 'PKG'],
#   'Tobacco': ['MO', 'PM']}}

# %% [markdown]
# # Simfin Integration
# #### Uses a nested dictionary for each segment of the CSV to create dataframes from Simfin data
# ##### Market Cap -> Industry

# %%
import numpy as np
import simfin as sf
from simfin.names import *

# %%
API_KEY = 'MbOGeJgi6qQjgYbb58oBVQDaObxEZzXg'

# SimFin data-directory.
sf.set_data_dir('~/simfin_data/')
# SimFin load API key or use free data.
sf.load_api_key('MbOGeJgi6qQjgYbb58oBVQDaObxEZzXg')

market = 'us'

# Add this date-offset to the fundamental data such as
# Income Statements etc., because the REPORT_DATE is not
# when it was actually made available to the public,
# which can be 1, 2 or even 3 months after the Report Date.
offset = pd.DateOffset(days=60)

# Refresh the fundamental datasets (Income Statements etc.)
# every 30 days.
refresh_days = 30

# Refresh the dataset with shareprices every 10 days.
refresh_days_shareprices = 10

hub = sf.StockHub(market=market, offset=offset,
                  refresh_days=refresh_days,
                  refresh_days_shareprices=refresh_days_shareprices)

df_fin_signals = hub.fin_signals(variant='daily')
df_growth_signals = hub.growth_signals(variant='daily')
df_val_signals = hub.val_signals(variant='daily')

# Combine the DataFrames.
dfs = [df_fin_signals, df_growth_signals, df_val_signals]
df_signals = pd.concat(dfs, axis=1)

# Remove all rows with only NaN values.
df = df_signals.dropna(how='all').reset_index(drop=True)

# List of the columns before removing any.
columns_before = df_signals.columns

# Threshold for the number of rows that must be NaN for each column.
thresh = 0.75 * len(df_signals.dropna(how='all'))

# Remove all columns which don't have sufficient data.
df_signals = df_signals.dropna(axis='columns', thresh=thresh)

# List of the columns after the removal.
columns_after = df_signals.columns

# Show the columns that were removed.
columns_before.difference(columns_after)

# Name of the new column for the returns.
TOTAL_RETURN_1_3Y = 'Total Return 1-3 Years'

# Calculate the mean log-returns for all 1-3 year periods.
df_returns_1_3y = \
    hub.mean_log_returns(name=TOTAL_RETURN_1_3Y,
                         future=True, annualized=True,
                         min_years=1, max_years=3)

dfs = [df_signals, df_returns_1_3y]
df_sig_rets = pd.concat(dfs, axis=1)

# Clip the signals and returns at their 5% and 95% quantiles.
# We do not set them to NaN because it would remove too much data.
df_sig_rets = sf.winsorize(df_sig_rets)

# Remove all rows with missing values (NaN)
# because scikit-learn cannot handle that.
df_sig_rets = df_sig_rets.dropna(how='any')

# Remove all tickers which have less than 200 data-rows.
df_sig_rets = df_sig_rets.groupby(TICKER) \
                .filter(lambda df: len(df)>200)



# List of all unique stock-tickers in the dataset.
tickers = df_sig_rets.reset_index()[TICKER].unique()
# Out:
# Dataset "us-income-ttm" on disk (12 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-ttm" on disk (12 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-ttm" on disk (12 days old).
# - Loading from disk ... Done!
# Dataset "us-shareprices-daily" on disk (1 days old).
# - Loading from disk ... Done!
# Cache-file 'fin_signals-2a38bb7d.pickle' on disk (1 days old).
# - Loading from disk ... Done!
# Dataset "us-income-quarterly" on disk (12 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" on disk (12 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-quarterly" on disk (12 days old).
# - Loading from disk ... Done!
# Cache-file 'growth_signals-2a38bb7d.pickle' on disk (1 days old).
# - Loading from disk ... Done!
# Cache-file 'val_signals-739b68a6.pickle' on disk (1 days old).
# - Loading from disk ... Done!
# Cache-file 'mean_log_change-5cec82bd.pickle' on disk (1 days old).
# - Loading from disk ... Done!

# %% [markdown]
# ## Cap Segmented Simfin

# %%
#Make list of tickers from the simfin data
simfin_tickers = df_sig_rets.index.unique(level=0).to_list()
simfin_tickers
# Out:
# ['A',
#  'AAMC',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAWW',
#  'ABAX',
#  'ABBV',
#  'ABC',
#  'ABCD',
#  'ABG',
#  'ABM',
#  'ABMC',
#  'ABT',
#  'ACAD',
#  'ACAT',
#  'ACCO',
#  'ACET',
#  'ACHC',
#  'ACLS',
#  'ACLZ',
#  'ACN',
#  'ACRX',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADS',
#  'ADSK',
#  'AE',
#  'AEE',
#  'AEHR',
#  'AEP',
#  'AEPI',
#  'AES',
#  'AGCO',
#  'AGIO',
#  'AGN_old',
#  'AHPI',
#  'AHS',
#  'AIMC',
#  'AIR',
#  'AIRI',
#  'AIT',
#  'AJG',
#  'AJRD',
#  'AKAM',
#  'AKRX',
#  'AKS',
#  'AL',
#  'ALB',
#  'ALE',
#  'ALG',
#  'ALGT',
#  'ALJ',
#  'ALK',
#  'ALKS',
#  'ALLE',
#  'ALNY',
#  'ALSK',
#  'ALSN',
#  'ALV',
#  'ALXN',
#  'AMAT',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMKR',
#  'AMOT',
#  'AMP',
#  'AMRK',
#  'AMSC',
#  'AMSWA',
#  'AMT',
#  'AMTD',
#  'AMWD',
#  'AMZN',
#  'AN',
#  'ANDE',
#  'ANDV',
#  'ANET',
#  'ANF',
#  'ANIK',
#  'ANSS',
#  'AOBC',
#  'AOS',
#  'AOSL',
#  'APA',
#  'APC',
#  'APD',
#  'APH',
#  'APOG',
#  'ARCB',
#  'ARCW',
#  'ARE',
#  'AREX',
#  'ARG',
#  'ARQL',
#  'ARRS',
#  'ARRY',
#  'ARW',
#  'ASCMA',
#  'ASNA',
#  'ASPN',
#  'ATHN',
#  'ATI',
#  'ATR',
#  'ATRO',
#  'ATVI',
#  'ATW',
#  'AVA',
#  'AVAV',
#  'AVB',
#  'AVEO',
#  'AVGO_old',
#  'AVNW',
#  'AVP',
#  'AVY',
#  'AWK',
#  'AWRE',
#  'AWX',
#  'AXGN',
#  'AXL',
#  'AYI',
#  'AYR',
#  'AZO',
#  'AZZ',
#  'BA',
#  'BAH',
#  'BAX',
#  'BBBY',
#  'BBGI',
#  'BBRG',
#  'BBY',
#  'BC',
#  'BCO',
#  'BCPC',
#  'BCR',
#  'BDX',
#  'BFAM',
#  'BG',
#  'BGG',
#  'BHE',
#  'BHI',
#  'BID',
#  'BIG',
#  'BJRI',
#  'BKNG',
#  'BLDR',
#  'BLK',
#  'BLKB',
#  'BLL',
#  'BMI',
#  'BMRN',
#  'BMS',
#  'BNFT',
#  'BONT',
#  'BOOM',
#  'BRC',
#  'BRCD',
#  'BREW',
#  'BRO',
#  'BRRE',
#  'BRSS',
#  'BRX',
#  'BSPM',
#  'BSTC',
#  'BURL',
#  'BVSN',
#  'BWLA',
#  'BWXT',
#  'CA',
#  'CACI',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALD',
#  'CALL',
#  'CALM',
#  'CASY',
#  'CAT',
#  'CATS',
#  'CAVM',
#  'CBB',
#  'CBI',
#  'CBM',
#  'CBRL',
#  'CCE',
#  'CCF',
#  'CCI',
#  'CCK',
#  'CCL',
#  'CCMP',
#  'CCXI',
#  'CDE',
#  'CDK',
#  'CDW',
#  'CE',
#  'CELG',
#  'CENT',
#  'CERN',
#  'CF',
#  'CGA',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHEF',
#  'CHGG',
#  'CHK',
#  'CHKE',
#  'CHRW',
#  'CHSP',
#  'CHTR',
#  'CIDM',
#  'CIK',
#  'CL',
#  'CLAR',
#  'CLF',
#  'CLFD',
#  'CLH',
#  'CLNE',
#  'CLR',
#  'CLX',
#  'CMCO',
#  'CMD',
#  'CME',
#  'CMI',
#  'CMLS',
#  'CMP',
#  'CMPR',
#  'CMS',
#  'CMTL',
#  'CNA',
#  'CNC',
#  'CNP',
#  'CNSL',
#  'COG',
#  'COHR',
#  'COKE',
#  'COL',
#  'COLM',
#  'COMM',
#  'CONN',
#  'COP',
#  'COR',
#  'CORT',
#  'COTY',
#  'CPN',
#  'CPRI',
#  'CPRT',
#  'CPS',
#  'CPST',
#  'CPT',
#  'CQP',
#  'CR',
#  'CRIS',
#  'CRL',
#  'CRM',
#  'CRWS',
#  'CRY',
#  'CRZO',
#  'CSGP',
#  'CSGS',
#  'CSII',
#  'CSL',
#  'CSS',
#  'CSU',
#  'CSX',
#  'CTAS',
#  'CTIC',
#  'CTL',
#  'CTSH',
#  'CTXS',
#  'CUB',
#  'CUBE',
#  'CVCO',
#  'CVGI',
#  'CVSI',
#  'CVX',
#  'CXO',
#  'CXW',
#  'CYCC',
#  'CZR',
#  'D',
#  'DBD',
#  'DCI',
#  'DDD',
#  'DDE',
#  'DE',
#  'DENN',
#  'DEST',
#  'DF',
#  'DG',
#  'DGX',
#  'DHX',
#  'DIN',
#  'DISCA',
#  'DISH',
#  'DKS',
#  'DLB',
#  'DLTR',
#  'DLX',
#  'DNB',
#  'DOV',
#  'DRE',
#  'DRI',
#  'DRQ',
#  'DSW',
#  'DTE',
#  'DUK',
#  'DVAX',
#  'DVN',
#  'DXLG',
#  'DXPE',
#  'DY',
#  'DYNT',
#  'EAT',
#  'EBIX',
#  'ECYT',
#  'ED',
#  'EE',
#  'EEFT',
#  'EEI',
#  'EFOI',
#  'EFX',
#  'EGAN',
#  'EGP',
#  'EGY',
#  'EIGI',
#  'EL',
#  'ELMD',
#  'ELY',
#  'EME',
#  'EMN',
#  'ENDP',
#  'ENDP_old',
#  'ENG',
#  'ENPH',
#  'EOG',
#  'EPD',
#  'EPE',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'ERS',
#  'ES',
#  'ESCA',
#  'ESI',
#  'ESL',
#  'ESP',
#  'ES_old',
#  'ETEC',
#  'ETM',
#  'ETN',
#  'ETR',
#  'EV',
#  'EVC',
#  'EW',
#  'EXA',
#  'EXAS',
#  'EXP',
#  'EXPD',
#  'EXPR',
#  'EXR',
#  'EXTR',
#  'FARM',
#  'FAST',
#  'FB',
#  'FBHS',
#  'FC',
#  'FCEL',
#  'FDX',
#  'FELE',
#  'FEYE',
#  'FICO',
#  'FII',
#  'FIS',
#  'FISV',
#  'FIVE',
#  'FIVN',
#  'FIZZ',
#  'FLEX',
#  'FLIR',
#  'FLO',
#  'FLR',
#  'FLT',
#  'FLWS',
#  'FMC',
#  'FNSR',
#  'FONR',
#  'FORD',
#  'FORM',
#  'FOSL',
#  'FPRX',
#  'FRAN',
#  'FRGI',
#  'FRT',
#  'FSLR',
#  'FSS',
#  'FTEK',
#  'FTI_old',
#  'FTNT',
#  'FUL',
#  'Fred',
#  'GBX',
#  'GCO',
#  'GD',
#  'GDOT',
#  'GENC',
#  'GEO',
#  'GEOS',
#  'GES',
#  'GGG',
#  'GHC',
#  'GHDX',
#  'GIII',
#  'GILD',
#  'GIS',
#  'GLGI',
#  'GLW',
#  'GME',
#  'GMED',
#  'GOOD',
#  'GPRE',
#  'GPS',
#  'GRMN',
#  'GT',
#  'GUID',
#  'GWR',
#  'GWRE',
#  'GWW',
#  'GXP',
#  'H',
#  'HAL',
#  'HALO',
#  'HAS',
#  'HAYN',
#  'HBI',
#  'HCA',
#  'HCOM',
#  'HDSN',
#  'HEAR',
#  'HEI',
#  'HELE',
#  'HGEN',
#  'HI',
#  'HII',
#  'HIL',
#  'HLF',
#  'HLS',
#  'HMHC',
#  'HMTV',
#  'HNI',
#  'HNNA',
#  'HOG',
#  'HOLX',
#  'HON',
#  'HP',
#  'HPJ',
#  'HRC',
#  'HRL',
#  'HRS',
#  'HSIC',
#  'HSII',
#  'HST',
#  'HSY',
#  'HUN',
#  'HURC',
#  'HURN',
#  'HXL',
#  'IAC',
#  'IART',
#  'IDA',
#  'IDT',
#  'IDXX',
#  'IEHC',
#  'IEX',
#  'IFF',
#  'IFON',
#  'IGT',
#  'IIN',
#  'ILMN',
#  'INCY',
#  'INGR',
#  'INTU',
#  'INVA',
#  'IO',
#  'IP',
#  'IPAR',
#  'IPDN',
#  'IPG',
#  'IPGP',
#  'IPI',
#  'IPXL',
#  'IQV',
#  'IRM',
#  'ISIL',
#  'ISSC',
#  'IT',
#  'ITGR',
#  'ITRI',
#  'ITW',
#  'IVAC',
#  'JAKK',
#  'JAZZ',
#  'JBHT',
#  'JBLU',
#  'JCOM',
#  'JCP',
#  'JJSF',
#  'JKHY',
#  'JMBA',
#  'JNJ',
#  'JOUT',
#  'JOY',
#  'JVA',
#  'JWA',
#  'JWN',
#  'K',
#  'KAR',
#  'KDP',
#  'KE',
#  'KEM',
#  'KIRK',
#  'KLAC',
#  'KLIC',
#  'KMB',
#  'KMG',
#  'KMI',
#  'KMX',
#  'KND',
#  'KO',
#  'KOPN',
#  'KRA',
#  'KRO',
#  'KSS',
#  'KSU',
#  'KTOS',
#  'KWR',
#  'LABL',
#  'LAYN',
#  'LB',
#  'LBTYA',
#  'LCI',
#  'LCUT',
#  'LDOS_old',
#  'LEA',
#  'LEDS',
#  'LEE',
#  'LEG',
#  'LGIH',
#  'LGL',
#  'LH',
#  'LHCG',
#  'LII',
#  'LIVE',
#  'LKQ',
#  'LLL',
#  'LMT',
#  'LNG',
#  'LNN',
#  'LNT',
#  'LOGI',
#  'LOGM',
#  'LOPE',
#  'LPLA',
#  'LPTH',
#  'LSI',
#  'LSTR',
#  'LTRPA',
#  'LTRX',
#  'LUV',
#  'LXRX',
#  'LYB',
#  'LYV',
#  'LZB',
#  'M',
#  'MA',
#  'MAMS',
#  'MAR',
#  'MAT',
#  'MATX',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'MD',
#  'MDP',
#  'MDR',
#  'MDRX',
#  'MDSO',
#  'MEET',
#  'MELI',
#  'MFON',
#  'MGEE',
#  'MGLN',
#  'MGM',
#  'MGPI',
#  'MHH',
#  'MHK',
#  'MIC',
#  'MIND',
#  'MITK',
#  'MJN',
#  'MKC',
#  'MKSI',
#  'MLM',
#  'MMI',
#  'MMM',
#  'MMS',
#  'MN',
#  'MNI',
#  'MO',
#  'MON',
#  'MORN',
#  'MOS',
#  'MOV',
#  'MPC',
#  'MPX',
#  'MRC',
#  'MRCY',
#  'MRVL',
#  'MSA',
#  'MSCC',
#  'MSCI',
#  'MSI',
#  'MTBC',
#  'MTEM',
#  'MTN',
#  'MTRN',
#  'MTRX',
#  'MTSI',
#  'MTZ',
#  'MU',
#  'MUR',
#  'MYGN',
#  'MYL_old',
#  'Mac',
#  'NAII',
#  'NANO',
#  'NATI',
#  'NAV',
#  'NBL',
#  'NCMI',
#  'NDAQ',
#  'NDLS',
#  'NDSN',
#  'NE',
#  'NEE',
#  'NEM',
#  'NEO',
#  'NEOG',
#  'NEP',
#  'NFLX',
#  'NGVC',
#  'NI',
#  'NICK',
#  'NJR',
#  'NKE',
#  'NKTR',
#  'NLNK',
#  'NLS',
#  'NLSN',
#  'NOC',
#  'NOV',
#  'NP',
#  'NPTN',
#  'NRG',
#  'NSC',
#  'NSSC',
#  'NTAP',
#  'NTRI',
#  'NUAN',
#  'NUE',
#  'NUTR',
#  'NUVA',
#  'NVAX',
#  'NVDA',
#  'NVEC',
#  'NVR',
#  'NWL',
#  'NWS',
#  'NWY',
#  'NX',
#  'NXST',
#  'NYT',
#  'O',
#  'OCC',
#  'ODP',
#  'OFLX',
#  'OGS',
#  'OHI',
#  'OI',
#  'OII',
#  'OKE',
#  'OLED',
#  'OLN',
#  'OMC',
#  'OMI',
#  'ON',
#  'ONVO',
#  'ORCL',
#  'ORLY',
#  'OSIS',
#  'OSK',
#  'OSTK',
#  'OTEX',
#  'OUT',
#  'OXM',
#  'OXY',
#  'PACB',
#  'PAHC',
#  'PANW',
#  'PATK',
#  'PAYC',
#  'PBH',
#  'PCG',
#  'PCMI',
#  'PDCO',
#  'PDEX',
#  'PEB',
#  'PEG',
#  'PEGA',
#  'PERF',
#  'PESI',
#  'PETS',
#  'PG',
#  'PH',
#  'PHM',
#  'PII',
#  'PIR',
#  'PKG',
#  'PLCE',
#  'PLD',
#  'PLPC',
#  'PM',
#  'PNRA',
#  'PNW',
#  'PODD',
#  'PPC',
#  'PPG',
#  'PPL',
#  'PPSI',
#  'PRCP',
#  'PRGO',
#  'PRGS',
#  'PRKA',
#  'PRTS',
#  'PRXL',
#  'PSA',
#  'PSDV',
#  'PSX',
#  'PTEN',
#  'PTN',
#  'PURE',
#  'PVH',
#  'PX',
#  'PXD',
#  'PYX',
#  'QEP',
#  'QNST',
#  'QSII',
#  'QUOT',
#  'RAD',
#  'RAI',
#  'RAIL',
#  'RAX',
#  'RCII',
#  'RCL',
#  'RDC',
#  'RDNT',
#  'RECN',
#  'REED',
#  'REGN',
#  'RES',
#  'RESI',
#  'REV',
#  'RFP',
#  'RGC',
#  'RGEN',
#  'RHI',
#  'RHT',
#  'RICK',
#  'RIG',
#  'RIGL',
#  'RL',
#  'RLGY',
#  'RMCF',
#  'RMD',
#  'ROCK',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RP',
#  'RPM',
#  'RS',
#  'RSG',
#  'RST',
#  'RSYS',
#  'RT',
#  'RTN',
#  'RUBI',
#  'RUSHA',
#  'RWC',
#  'RYAM',
#  'RYN',
#  'SABR',
#  'SAFM',
#  'SAIA',
#  'SAM',
#  'SANM',
#  'SANW',
#  'SAVE',
#  'SBAC',
#  'SBGI',
#  'SBH',
#  'SBUX',
#  'SCND',
#  'SCSC',
#  'SCVL',
#  'SEAS',
#  'SEB',
#  'SEV',
#  'SFLY',
#  'SFM',
#  'SGMA',
#  'SHLD',
#  'SHLM',
#  'SHLO',
#  'SHO',
#  'SHOR',
#  'SHOS',
#  'SHPGF',
#  'SHW',
#  'SIG',
#  'SIRI',
#  'SIX',
#  'SJM',
#  'SKX',
#  'SLB',
#  'SLCA',
#  'SLNM',
#  'SMED',
#  'SMLP',
#  'SMP',
#  'SMRT',
#  'SMTC',
#  'SNA',
#  'SNAK',
#  'SNDK',
#  'SNH',
#  'SNHY',
#  'SNI',
#  'SNX',
#  'SOFO',
#  'SOHO',
#  'SOHU',
#  'SON',
#  'SONC',
#  'SORL',
#  'SOTK',
#  'SPAN',
#  'SPB',
#  'SPG',
#  'SPLS',
#  'SPNC',
#  'SPPI',
#  'SRCL',
#  'SRE',
#  'SSI',
#  'SSNC',
#  'SSNI',
#  'SSNT',
#  'SSP',
#  'ST',
#  'STAY',
#  'STLD',
#  'STRM',
#  'STX',
#  'STZ',
#  'SUPN',
#  'SVT',
#  'SWK',
#  'SWKS',
#  'SWM',
#  'SWX',
#  'SXC',
#  'SXT',
#  'SYNA',
#  'T',
#  'TA',
#  'TAP',
#  'TAST',
#  'TBTC',
#  'TDG',
#  'TECH',
#  'TEL',
#  'TESO',
#  'TESS',
#  'TFX',
#  'TGT',
#  'THO',
#  'THS',
#  'TIS',
#  'TITN',
#  'TIVO',
#  'TJX',
#  'TLYS',
#  'TNDM',
#  'TNET',
#  'TOL',
#  'TPCS',
#  'TPR',
#  'TPX',
#  'TREE',
#  'TREX',
#  'TRGP',
#  'TRIP',
#  'TRMB',
#  'TRNS',
#  'TRT',
#  'TRU',
#  'TRUE',
#  'TRUP',
#  'TSCO',
#  'TSE',
#  'TSLA',
#  'TSN',
#  'TSSI',
#  'TTGT',
#  'TTMI',
#  'TUES',
#  'TUP',
#  'TWI',
#  'TWIN',
#  'TWOU',
#  'TWTR',
#  'TWX',
#  'TXMD',
#  'TXN',
#  'TXRH',
#  'TYPE',
#  'UAL',
#  'UDR',
#  'UFI',
#  'UFS',
#  'UHAL',
#  'UHS',
#  'UIS',
#  'ULBI',
#  'ULTA',
#  'UNFI',
#  'UNH',
#  'UNP',
#  'UPS',
#  'URI',
#  'USAP',
#  'USAT',
#  'USCR',
#  'USM',
#  'USNA',
#  'UTHR',
#  'UTX',
#  'V',
#  'VAL',
#  'VAR',
#  'VDSI',
#  'VFC',
#  'VIAB',
#  'VIDE',
#  'VIRC',
#  'VLGEA',
#  'VMC',
#  'VMI',
#  'VMW',
#  'VNCE',
#  'VNO',
#  'VRA',
#  'VRNT',
#  'VRSK',
#  'VRSN',
#  'VRTU',
#  'VRTX',
#  'VRX',
#  'VTR',
#  'VZ',
#  'WAB',
#  'WAT',
#  'WBC',
#  'WCG',
#  'WDC',
#  'WEC',
#  'WELL',
#  'WEN',
#  ...]

# %%
#initialize cap segmented ticker lists
simfin_mega = list()
simfin_large = list()
simfin_mid = list()
simfin_small = list()
simfin_micro = list()

# %%
#check initial cap value and assign tickers accordingly
for ticker in simfin_tickers:
    init_date = df_sig_rets.loc[[ticker]].index.get_level_values(1).min()
    init_cap = df_sig_rets.loc[(ticker, init_date)]['Market-Cap']
    if init_cap >= 2.0e11:
        simfin_mega.append(ticker)
    elif (init_cap >= 1.0e10) & (init_cap < 2.0e11):   
        simfin_large.append(ticker)
    elif (init_cap >= 2.0e9) & (init_cap < 1.0e10):  
        simfin_mid.append(ticker)
    elif (init_cap >= 3.0e08) & (init_cap < 2.0e09):  
        simfin_small.append(ticker)
    elif (init_cap >= 5.0e07) & (init_cap < 3.0e08):  
        simfin_micro.append(ticker)

# %%
#create cap segmented dataframes
if simfin_mega:
    df_sig_rets_mega = df_sig_rets.loc[simfin_mega]
if simfin_large:
    df_sig_rets_large = df_sig_rets.loc[simfin_large]
if simfin_mid:
    df_sig_rets_mid = df_sig_rets.loc[simfin_mid]
if simfin_small:
    df_sig_rets_small = df_sig_rets.loc[simfin_small]
if simfin_micro:
    df_sig_rets_micro = df_sig_rets.loc[simfin_micro]

# %%
df_sig_rets_micro
# Out:
#                    (Dividends + Share Buyback) / FCF  Asset Turnover  \
# Ticker Date
# AAOI   2014-12-01                           2.188082        0.700560
#        2014-12-02                           2.188082        0.700560
#        2014-12-03                           2.188082        0.700560
#        2014-12-04                           2.188082        0.700560
#        2014-12-05                           2.188082        0.700560
# ...                                              ...             ...
# ZGNX   2016-06-16                           0.000000        0.122127
#        2016-06-17                           0.000000        0.122127
#        2016-06-20                           0.000000        0.122127
#        2016-06-21                           0.000000        0.122127
#        2016-06-22                           0.000000        0.122127
#
#                    CapEx / (Depr + Amor)  Current Ratio  Dividends / FCF  \
# Ticker Date
# AAOI   2014-12-01               3.347826       2.838472              0.0
#        2014-12-02               3.347826       2.838472              0.0
#        2014-12-03               3.347826       2.838472              0.0
#        2014-12-04               3.347826       2.838472              0.0
#        2014-12-05               3.347826       2.838472              0.0
# ...                                  ...            ...              ...
# ZGNX   2016-06-16               0.209838       7.868594              0.0
#        2016-06-17               0.209838       7.868594              0.0
#        2016-06-20               0.209838       7.868594              0.0
#        2016-06-21               0.209838       7.868594              0.0
#        2016-06-22               0.209838       7.868594              0.0
#
#                    Gross Profit Margin  Interest Coverage  Log Revenue  \
# Ticker Date
# AAOI   2014-12-01             0.328195          24.650350     8.071153
#        2014-12-02             0.328195          24.650350     8.071153
#        2014-12-03             0.328195          24.650350     8.071153
#        2014-12-04             0.328195          24.650350     8.071153
#        2014-12-05             0.328195          24.650350     8.071153
# ...                                ...                ...          ...
# ZGNX   2016-06-16             0.174262         -17.744338     7.502072
#        2016-06-17             0.174262         -17.744338     7.502072
#        2016-06-20             0.174262         -17.744338     7.502072
#        2016-06-21             0.174262         -17.744338     7.502072
#        2016-06-22             0.174262         -17.744338     7.502072
#
#                    Net Profit Margin  Quick Ratio  ...  FCF Yield  \
# Ticker Date                                        ...
# AAOI   2014-12-01           0.025976     1.769900  ...  -0.186366
#        2014-12-02           0.025976     1.769900  ...  -0.191398
#        2014-12-03           0.025976     1.769900  ...  -0.188569
#        2014-12-04           0.025976     1.769900  ...  -0.191589
#        2014-12-05           0.025976     1.769900  ...  -0.188755
# ...                              ...          ...  ...        ...
# ZGNX   2016-06-16           0.275968     6.495311  ...  -0.244200
#        2016-06-17           0.275968     6.495311  ...  -0.244200
#        2016-06-20           0.275968     6.495311  ...  -0.244200
#        2016-06-21           0.275968     6.495311  ...  -0.244200
#        2016-06-22           0.275968     6.495311  ...  -0.244200
#
#                      Market-Cap    P/Book    P/Cash        P/E     P/FCF  \
# Ticker Date
# AAOI   2014-12-01  1.930558e+08  1.696135  4.290891  63.090117 -5.365790
#        2014-12-02  1.879803e+08  1.651543  4.178083  61.431467 -5.224722
#        2014-12-03  1.908000e+08  1.676316  4.240754  62.352939 -5.303093
#        2014-12-04  1.877923e+08  1.649892  4.173904  61.370036 -5.219498
#        2014-12-05  1.906120e+08  1.674665  4.236576  62.291508 -5.297869
# ...                         ...       ...       ...        ...       ...
# ZGNX   2016-06-16  2.007367e+08  1.154595  1.809046   5.198278 -3.116642
#        2016-06-17  1.888615e+08  1.086291  1.809046   4.890757 -2.932267
#        2016-06-20  1.886331e+08  1.084978  1.809046   4.884843 -2.928722
#        2016-06-21  1.874913e+08  1.078410  1.809046   4.855274 -2.910993
#        2016-06-22  1.895466e+08  1.090232  1.809046   4.908499 -2.942904
#
#                      P/NCAV  P/NetNet   P/Sales  Total Return 1-3 Years
# Ticker Date
# AAOI   2014-12-01  3.410698  7.612834  1.638816                0.442427
#        2014-12-02  3.321031  7.412691  1.595731                0.457723
#        2014-12-03  3.370846  7.523882  1.619667                0.450279
#        2014-12-04  3.317709  7.405279  1.594135                0.459732
#        2014-12-05  3.367525  7.516469  1.618071                0.452311
# ...                     ...       ...       ...                     ...
# ZGNX   2016-06-16  3.990392  7.209463  6.317640                0.482756
#        2016-06-17  3.754328  6.782965  5.943900                0.482756
#        2016-06-20  3.749788  6.774763  5.936713                0.482756
#        2016-06-21  3.727090  6.733753  5.900776                0.482756
#        2016-06-22  3.767947  6.807570  5.965462                0.482756
#
# [115551 rows x 36 columns]

# %% [markdown]
# ## Sector Segmented Simfin

# %%
d_sf = {}
#create dictionary which holds all simfin tickers per industry (from finhub data)
for cap, industry in d.items():
    for i, tlist in industry.items():
        if len(tlist) == 0:
            continue
        try: 
            d_sf[i]
        except KeyError:
            d_sf[i] = list()
        for ticker in tlist:
            if ticker not in simfin_tickers:
                continue
            d_sf[i].append(ticker)
d_sf

# %%
#create segmented values for simfin data per sector
d_simfin_sectors = {}
for k in d_sf.keys():
    d_simfin_sectors[k] = df_sig_rets.loc[d_sf[k]]

# %%
d_sf['Tobacco']

# %%
df_sig_rets.loc[d_sf['Tobacco']]

# %%
d_simfin_sectors['Tobacco']
